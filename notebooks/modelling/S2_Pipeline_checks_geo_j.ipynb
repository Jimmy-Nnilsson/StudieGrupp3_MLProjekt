# %%
# Setup if running in colab
RunningInCOLAB = 'google.colab' in str(get_ipython())
if RunningInCOLAB:
  try:
    if runonce:
      print("Already ran")
  
  except:
    runonce = True
    # !pip install wandb
    # !git clone https://github.com/Jimmy-Nnilsson/StudieGrupp3_MLProjekt.git
    
    # import wandb
    # wandb.login()

# %%
# import wandb
# wandb.login()

# %%
import os
import numpy as np
import random
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import tensorflow as tf
print("TF: ", tf.__version__)
from tensorflow.keras import layers
from tensorflow.keras import models
from keras import Model
import keras

from pathlib import Path
from keras.preprocessing.image import load_img, img_to_array, image_dataset_from_directory
from tensorflow.keras.applications import vgg16, vgg19, mobilenet_v2, inception_v3
from sklearn.metrics import confusion_matrix, classification_report

import wandb
from wandb.keras import WandbCallback

import cv2
# Out:
# TF:  2.7.0

# %%
def seed_everything():
    # os.environ['PYTHONHASHSEED'] = '0'
    os.environ['TF_CUDNN_DETERMINISTIC'] = '1' 
    random.seed(1254)
    np.random.seed(hash("improves reproducibility") % 2**32 - 1)
    tf.random.set_seed(hash("by removing stochasticity") % 2**32 - 1)

seed_everything()

# %%
# Out:
# 2
# p:\Python\StudieGrupp3_MLProjekt

# %%
# Get base project directory
if not RunningInCOLAB:
#   project_path = Path(os.getcwd()).parent.parent

  for i, p in enumerate(Path(os.getcwd()).parts):
    if p == "StudieGrupp3_MLProjekt":
        break
    pathparts = list(Path(os.getcwd()).parts[0:i+2])
    project_path = Path(pathparts[0],"\\\\".join(pathparts[1:]))
else:
  project_path = Path('/content/StudieGrupp3_MLProjekt/')
datapath = (project_path /'data/processed/')

CLASSES = {0 : 'yes', 1 : 'no'}
# Loops through pathlist and reads and resizes images
def read_image(pathlist : list, size : int)-> list:
    data = []
    for path in pathlist:
        image=load_img(path, color_mode='rgb', target_size=(size, size))
        # image=load_img(path, color_mode='rgb', target_size=(size, size))
        image=img_to_array(image)
        # image=image/255.0
        data.append(image)
    data = np.asarray(data, dtype=np.uint8)
    return data

# Makes input and label data from folder locations.
# Loops through location "subfolder/CLASSES"
def get_sets(subfolder : str, CLASSES : dict, size : int):
    folder_paths = []
    folder_labels = []
    labels = []
    for k,v in CLASSES.items():
        # input datapath generation
        folder_paths += list((datapath / f"2_split_{v}/{subfolder}").rglob("*"))
    # Label data generation
    folder_labels = [0 if x.stem.split('_')[1] == 'yes' else 1 for x in folder_paths]
    folder_labels = np.asarray(folder_labels, dtype=np.uint8)
    # Extract images from datapaths
    img_list = read_image(folder_paths, size)

    return img_list, folder_labels

def get_training_set(CLASSES : dict, size : int):
    folder_paths = []
    folder_labels = []
    labels = []
    for k,v in CLASSES.items():
        # input datapath generation
        # folder_paths += list((datapath / f"3_aug_{v}_train/").rglob("*"))
        folder_paths += list((datapath / f"3_augmentation_train/3_aug_geo_{v}_train/").rglob("*"))
        # folder_paths += list((datapath / f"3_augmentation_train/3_aug_pix_{v}_train/").rglob("*"))
        # print(folder_paths)
    # Label data generation
    folder_labels = [0 if x.stem.split('_')[1] == 'yes' else 1 for x in folder_paths]
    # Extract images from datapaths
    img_list = read_image(folder_paths, size)

    return img_list, folder_labels

# %%
pathparts
# Out:
# ['p:\\', 'Python', 'StudieGrupp3_MLProjekt']

# %% [markdown]
# Load Pictures

# %%
# Dataset inspect
# Read images to variables
size = 224
X_aug_train, y_aug_train = get_training_set(CLASSES, size)
X_train, y_train = get_sets('train', CLASSES, size)
X_val, y_val = get_sets('val', CLASSES, size)
X_test, y_test = get_sets('test', CLASSES, size)

# %%
#@title
@tf.function
def preprocess(image: tf.Tensor, label: tf.Tensor):
    """
    Preprocess the image tensors and parse the labels
    """
    # Preprocess images
    image = tf.image.convert_image_dtype(image, tf.float32)

    # Parse label
    label = tf.cast(label, tf.float32)

    return image, label


def prepare_dataloader(images: np.ndarray,
                       labels: np.ndarray,
                       loader_type: str='train',
                       batch_size: int=128):
    """
    Utility function to prepare dataloader.
    """
    images = model_preprocess(images)
    dataset = tf.data.Dataset.from_tensor_slices((images, labels))

    if loader_type=='train':
        dataset = dataset.shuffle(1024)

    dataloader = (
        dataset
        .map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
        .batch(batch_size)
        .prefetch(tf.data.AUTOTUNE)
    )

    return dataloader

def model_preprocess(images):
    images = vgg19.preprocess_input(images)
    # images = vgg16.preprocess_input(images)
    # images = mobilenet_v2.preprocess_input(images)
    # images = inception_v3.preprocess_input(images)
    
    return images

# %% [markdown]
# Config parameters

# %%
# Mind model processing
# Finetune not complete
configs = dict(
    project_name = "MRI_Baseline_3", #Project Name
    mode = 'disabled', #{'offline', 'run', 'disabled', 'dryrun', 'online'} # WandB run status
    job_type = "", #Run type for WandB
    group = "", # Group in WandB
    sub_group = "_pipeline",

    class_names = CLASSES, # Classes for training
    training_set = "",

    image_width = X_train[0].shape[0], # Picture width for model input
    image_height = X_train[0].shape[1], # Picture height for model input
    image_channels = X_train[0].shape[2], # Picture channels for model input

    pretrain_weights = 'imagenet', # pretrained weights for basemodel if any
    batch_size = 4, # Batchsize for training
    init_learning_rate = 0.001, # Initial training rate if no callback is used
    lr_decay_rate = 0.1, #decayrate of training rate
    epochs = 50, # Epochs to train
    optimizer = 'rmsprop', # The optimizer used by the ml model
    loss_fn = 'binary_crossentropy', # Loss function
    metrics = ['accuracy'], # Metrics
    earlystopping_patience = 5, # For the early stopping callback

    dataset = "Brain_MRI_Images_for_Brain_Tumor_Detection",
    fine_tune_learning_rate = 1e-5, # learningrate Used during fine tuning
    fine_tune_epochs = 10, # Epochs ran at finetuning

    architecture = "",# To be defined f"{base_model._name.upper()} global_average_pooling2d",
    model_name = '' # set after model is defined # Name of the ml Model

)

# %%
trainloader = prepare_dataloader(X_train, y_train, 'train', configs.get('batch_size', 64))
augtrainloader = prepare_dataloader(X_aug_train, y_aug_train, 'train', configs.get('batch_size', 64))
validloader = prepare_dataloader(X_val, y_val, 'valid', configs.get('batch_size', 64))
testloader = prepare_dataloader(X_test, y_test, 'test', configs.get('batch_size', 64))

# %%
configs['training_set'] = augtrainloader

# %% [markdown]
# Model class definition

# %%
class Model_Class():
    def __init__(self,
                 output_activation: str='sigmoid'
                 ):

        self.shape = (configs['image_width'],configs['image_height'], configs['image_channels'])
        self.model = ""
        # self.base_model = ""
        self.output_activation = output_activation
        self.run = ""
        self.get_model()
        self.conv_layers, self.layer_names = self.__get_convlayers()
        self.preds = ""
        if not wandb.run is None: wandb.finish()

    def get_model(self):
        tf.keras.backend.clear_session()
        kwarg = dict(weights=configs['pretrain_weights'], include_top=False, input_shape=self.shape)
        self.base_model = vgg19.VGG19(**kwarg)
        # self.base_model = vgg16.VGG16(**kwarg)
        # self.base_model = mobilenet_v2.MobileNetV2(**kwarg)
        # self.base_model = inception_v3.InceptionV3(**kwarg)
        
        self.base_model.trainable = False

        x = layers.GlobalAveragePooling2D()(self.base_model.output)
        # x = layers.Flatten()(self.base_model.output)

        x = layers.Dense(128, activation='relu')(x)
        x = layers.Dense(64, activation='relu')(x)
        x = layers.Dense(32, activation='relu')(x)
        outputs = layers.Dense(1, activation=self.output_activation)(x)
        configs['group'] = f'{self.base_model._name}{configs["sub_group"]}'
        configs['architecture'] = self.base_model._name
        self.model  = models.Model(self.base_model.input, outputs, name=f'Baseline_{self.base_model._name.upper()}')

    def transfer_learning(self,
        callbacks: list,
        verbose: int=0,
        wb: bool=False): # Makes training run on all but base model

        train_config = {
            "learning_rate" : configs['init_learning_rate'],
            "epochs" : configs['epochs'],
            "compile" : True}
        configs['job_type'] = "Transfer learning"

        self.base_model.trainable = False
        self.__train(callbacks=callbacks, verbose=verbose, wb=wb, train_config=train_config)

    def fine_tune(self,
        callbacks: list,
        verbose: int=0,
        wb: bool=False,
        trainable_layers: list=0):

        train_config = {
            "learning_rate" : configs['fine_tune_learning_rate'],
            "epochs" : configs['fine_tune_epochs'],
            'job_type' : 'Fine-tune',
            "compile" : False}
        configs['job_type'] = "Fine-tune"
        self.set_trainable(trainable_layers)
        self.__train(callbacks=callbacks, verbose=verbose, wb=wb, train_config=train_config)

    def __train(self,
        callbacks: list,
        verbose: int=0,
        wb: bool=False,
        train_config:dict={}
        ):

        if wb:
            callbacks.append(self.__wandb())

        # Initalize model
        # tf.keras.backend.clear_session()
        configs['model_name'] = self.model._name # set

        # Compile the model
        if train_config['compile']:
          opt = tf.keras.optimizers.RMSprop(learning_rate=train_config['learning_rate'])
          self.model.compile(optimizer=opt,
                      loss=configs['loss_fn'],
                      metrics=configs['metrics'])
        
        # Train model
        _ = self.model.fit(configs['training_set'],
                    epochs=train_config['epochs'],
                    validation_data=validloader,
                    callbacks=callbacks,
                    verbose=verbose)
        if wb:
            # Evaluate the trained model
            loss, acc = self.model.evaluate(validloader)
            self.run.log({'evaluate/accuracy': acc})


            # Close the W&B run.
            self.run.finish()

    def grad_cam(self, image, layer=None):
        self.preds = self.predict(image)

        if type(layer) is list:
            heatmap_list, superimposed_list = {},{}
            for layer_num in layer:
                heatmap = self.make_gradcam_heatmap(np.expand_dims(image, axis=0), layer_num, np.argmax(self.preds[0]))
                superimposed_img = self.superimpose(image,heatmap)
                heatmap_list[self.model.layers[layer_num]._name] = heatmap
                superimposed_list[self.model.layers[layer_num]._name] = superimposed_img
            return image, heatmap_list, superimposed_list
        else:
            heatmap = self.make_gradcam_heatmap(np.expand_dims(image, axis=0), layer, np.argmax(self.preds[0]))
            superimposed_img = self.superimpose(image,heatmap)
            return image, heatmap, superimposed_img


    def make_gradcam_heatmap(self, img_array, layer=None, pred_index=None):
        # First, we create a model that maps the input image to the activations
        # of the last conv layer as well as the output predictions
        if layer == None: layer=self.conv_layers[-1]
        model = self.model
        grad_model = Model(
            [model.inputs], [model.layers[layer].output, model.output]
            # [model.inputs], [model.get_layer(self.layer_names[-1]).output, model.output]
        )

        # Then, we compute the gradient of the top predicted class for our input image
        # with respect to the activations of the last conv layer
        with tf.GradientTape() as tape:
            last_conv_layer_output, preds = grad_model(img_array)
            if pred_index is None:
                pred_index = tf.argmax(preds[0])
            class_channel = preds[:, pred_index]

        # This is the gradient of the output neuron (top predicted or chosen)
        # with regard to the output feature map of the last conv layer
        grads = tape.gradient(class_channel, last_conv_layer_output)

        # This is a vector where each entry is the mean intensity of the gradient
        # over a specific feature map channel
        pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

        # We multiply each channel in the feature map array
        # by "how important this channel is" with regard to the top predicted class
        # then sum all the channels to obtain the heatmap class activation
        last_conv_layer_output = last_conv_layer_output[0]
        heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
        heatmap = tf.squeeze(heatmap)

        # For visualization purpose, we will also normalize the heatmap between 0 & 1
        heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
        return heatmap.numpy()

    def predict(self, pic):
        x = model_preprocess(pic)
        if len(x.shape) < 4:
          x = np.expand_dims(x, axis=0)
        
        preds = self.model.predict(x)
        return preds

    def superimpose(self, pic,heatmap):
        img_numpy = np.asarray(np.clip(pic, 0, 190))

        heatmap_resized = cv2.resize(heatmap, (img_numpy.shape[1], img_numpy.shape[0]))
        heatmap_resized = np.uint8(255 * heatmap_resized)
        heatmap_resized = cv2.applyColorMap(heatmap_resized, cv2.COLORMAP_JET)

        superimposed_img = 0.3*heatmap_resized[:,:,::-1] + img_numpy
        superimposed_img = superimposed_img.astype(np.uint8)
        return superimposed_img

    def __get_convlayers(self):
        list_conv_layers = []
        list_layer_names = []
        for i,l in enumerate(self.model.layers):
            # print(str(l).split('.'))
            if str(l).split('.')[2] == 'convolutional':
                list_conv_layers.append(i)
                list_layer_names.append(l._name)
        return list_conv_layers, list_layer_names

    def __wandb(self): 
        self.run = wandb.init(mode=configs['mode'] ,project=configs['project_name'], config=configs, job_type=configs['job_type'], group=configs['group'])

        # Define WandbCallback for experiment tracking
        wandb_callback = WandbCallback(monitor='val_loss',
                                    log_weights=True,
                                    log_evaluation=True,
                                    validation_steps=5,
                                    save_model=True,
                                    save_graph = True
                                    )
        return wandb_callback

    def set_trainable(self, trainable_layers=0): # Sets whole model to trainable
        if trainable_layers == 0:
            self.model.trainable = True
        else:
            self.model.trainable = False
            for i in trainable_layers:
                self.model.layers[i].trainable = True

# %% [markdown]
# Call model

# %%
model = Model_Class()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step
# 80150528/80134624 [==============================] - 1s 0us/step

# %% [markdown]
# Model Callbacks

# %%
model_filename = f'{model.base_model._name}_{configs["project_name"]}{configs["sub_group"]}.h5'
if not RunningInCOLAB:
  checkpoint_filepath = (Path(os.getcwd()) /f'model_checkpoint/{model_filename}')
else:
  checkpoint_filepath = (Path(f'/content/{model_filename}'))

model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %%
earlystopper = keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=configs['earlystopping_patience'], verbose=0, mode='auto',
    restore_best_weights=True
)

# %%
def lr_scheduler(epoch, lr):
    # log the current learning rate onto W&B
    if wandb.run is None:
        raise wandb.Error("You must call wandb.init() before WandbCallback()")

    wandb.log({'learning_rate': lr}, commit=False)

    if epoch < 12:
        return lr
    else:
        return lr * tf.math.exp(-configs['lr_decay_rate'])

lr_callback = tf.keras.callbacks.LearningRateScheduler(lr_scheduler)

# %% [markdown]
# Make gradcams

# %%
def plot_gradcam(image, heatmap, superimposed_img):
  if type(heatmap) == dict and type(superimposed_img) == dict:
      nlen = len(heatmap)
      fig, ax = plt.subplots(nlen,3, figsize=(10, nlen*3.5))
      # fig.figsize=(20,20)
      for i, (k, img) in enumerate(heatmap.items()):
          ax[i,0].imshow(img)
          ax[i,1].set_title(k)
          ax[i,1].imshow(superimposed_img[k])
          ax[i,2].imshow(image)
  else:
    plt.subplot(1,3, 1)
    plt.imshow(heatmap)
    plt.subplot(1,3, 2)
    plt.imshow(superimposed_img)
    plt.subplot(1,3, 3)
    plt.imshow(image)

# %%
# image, heatmap, superimposed_img = model.grad_cam(X_train[0], model.conv_layers)
# plot_gradcam(image, heatmap, superimposed_img)

# %% [markdown]
# Plot gradcams

# %%
image, heatmap, superimposed_img = model.grad_cam(X_train[0])
plot_gradcam(image, heatmap, superimposed_img)

# %%
import seaborn as sns

def crcm(model, x, y, p=True):
    y_pred = model.predict(x)
    y_pred = np.asarray(y_pred)
    y_pred = np.uint8(y_pred+0.5)
    cm = confusion_matrix(y, y_pred)
    cr = classification_report(y, y_pred)
    if p:
        plt.xlabel('Pred')
        sns.heatmap(cm, vmin=0, annot=True)
        print(cr)
    cr = classification_report(y, y_pred, output_dict=True )
    return cm, cr

# %%
cm_, cr_ = crcm(model, X_val, y_val)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        24
#            1       0.43      1.00      0.60        18
#
#     accuracy                           0.43        42
#    macro avg       0.21      0.50      0.30        42
# weighted avg       0.18      0.43      0.26        42
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Train with wandb

# %%
model.get_model()

# %%
import pandas as pd
df = pd.DataFrame
cr_list = []
cm_list = []
# callbacks = [earlystopper]
# callbacks = [model_checkpoint_callback]
callbacks = []
for i in range(5):
    model.get_model()
    # Train
    # model.train(callbacks=callbacks, verbose=2, wb=True)

    model.transfer_learning(callbacks=callbacks, verbose=2, wb=True)

    # model.model.summary()
    cm_, cr_ = crcm(model, X_val, y_val, p=False)
    cm_list.append(cm_)
    cr_['pos'] = {'precision': i,
  'recall': i,
  'f1-score': i,
  'support': i}
    if i > 0:
        df = df.append(pd.DataFrame.from_dict(cr_))
    else:
        df = pd.DataFrame.from_dict(cr_)
df.mean(level=0)
# Out:
# Epoch 1/50
# 500/500 - 22s - loss: 0.3935 - accuracy: 0.8515 - val_loss: 0.6983 - val_accuracy: 0.7857 - 22s/epoch - 43ms/step
# Epoch 2/50
# 500/500 - 18s - loss: 0.2214 - accuracy: 0.9200 - val_loss: 0.4741 - val_accuracy: 0.8571 - 18s/epoch - 36ms/step
# Epoch 3/50
# 500/500 - 18s - loss: 0.1639 - accuracy: 0.9425 - val_loss: 0.4231 - val_accuracy: 0.8571 - 18s/epoch - 36ms/step
# Epoch 4/50
# 500/500 - 18s - loss: 0.1202 - accuracy: 0.9615 - val_loss: 2.3862 - val_accuracy: 0.6667 - 18s/epoch - 36ms/step
# Epoch 5/50
# 500/500 - 18s - loss: 0.1055 - accuracy: 0.9700 - val_loss: 0.7813 - val_accuracy: 0.8810 - 18s/epoch - 37ms/step
# Epoch 6/50
# 500/500 - 18s - loss: 0.0833 - accuracy: 0.9740 - val_loss: 0.5966 - val_accuracy: 0.8571 - 18s/epoch - 37ms/step
# Epoch 7/50
# 500/500 - 18s - loss: 0.0912 - accuracy: 0.9810 - val_loss: 0.6461 - val_accuracy: 0.9048 - 18s/epoch - 37ms/step
# Epoch 8/50
# 500/500 - 18s - loss: 0.0752 - accuracy: 0.9820 - val_loss: 1.8372 - val_accuracy: 0.8095 - 18s/epoch - 37ms/step
# Epoch 9/50
# 500/500 - 19s - loss: 0.0604 - accuracy: 0.9870 - val_loss: 0.9953 - val_accuracy: 0.8810 - 19s/epoch - 37ms/step
# Epoch 10/50
# 500/500 - 19s - loss: 0.0751 - accuracy: 0.9875 - val_loss: 0.6150 - val_accuracy: 0.9286 - 19s/epoch - 37ms/step
# Epoch 11/50
# 500/500 - 19s - loss: 0.0559 - accuracy: 0.9870 - val_loss: 0.8011 - val_accuracy: 0.8571 - 19s/epoch - 37ms/step
# Epoch 12/50
# 500/500 - 19s - loss: 0.0507 - accuracy: 0.9915 - val_loss: 0.6337 - val_accuracy: 0.9048 - 19s/epoch - 37ms/step
# Epoch 13/50
# 500/500 - 19s - loss: 0.0674 - accuracy: 0.9910 - val_loss: 1.4998 - val_accuracy: 0.8810 - 19s/epoch - 37ms/step
# Epoch 14/50
# 500/500 - 19s - loss: 0.0434 - accuracy: 0.9920 - val_loss: 1.4123 - val_accuracy: 0.8333 - 19s/epoch - 37ms/step
# Epoch 15/50
# 500/500 - 19s - loss: 0.0284 - accuracy: 0.9960 - val_loss: 1.4408 - val_accuracy: 0.8571 - 19s/epoch - 37ms/step
# Epoch 16/50
# 500/500 - 19s - loss: 0.0181 - accuracy: 0.9975 - val_loss: 1.9237 - val_accuracy: 0.8571 - 19s/epoch - 38ms/step
# Epoch 17/50
# 500/500 - 19s - loss: 0.0358 - accuracy: 0.9955 - val_loss: 1.6658 - val_accuracy: 0.8333 - 19s/epoch - 38ms/step
# Epoch 18/50
# 500/500 - 19s - loss: 0.0532 - accuracy: 0.9925 - val_loss: 1.8994 - val_accuracy: 0.8333 - 19s/epoch - 38ms/step
# Epoch 19/50
# 500/500 - 19s - loss: 0.0643 - accuracy: 0.9940 - val_loss: 1.3612 - val_accuracy: 0.8095 - 19s/epoch - 38ms/step
# Epoch 20/50
# 500/500 - 19s - loss: 0.0388 - accuracy: 0.9950 - val_loss: 1.6158 - val_accuracy: 0.8095 - 19s/epoch - 38ms/step
# Epoch 21/50
# 500/500 - 19s - loss: 0.0399 - accuracy: 0.9945 - val_loss: 2.3136 - val_accuracy: 0.8571 - 19s/epoch - 39ms/step
# Epoch 22/50
# 500/500 - 19s - loss: 0.0413 - accuracy: 0.9955 - val_loss: 3.0149 - val_accuracy: 0.8095 - 19s/epoch - 38ms/step
# Epoch 23/50
# 500/500 - 19s - loss: 0.0392 - accuracy: 0.9950 - val_loss: 2.4932 - val_accuracy: 0.8333 - 19s/epoch - 38ms/step
# Epoch 24/50
# 500/500 - 19s - loss: 0.0575 - accuracy: 0.9945 - val_loss: 1.5343 - val_accuracy: 0.8571 - 19s/epoch - 39ms/step
# Epoch 25/50
# 500/500 - 19s - loss: 0.0382 - accuracy: 0.9960 - val_loss: 1.3630 - val_accuracy: 0.9048 - 19s/epoch - 38ms/step
# Epoch 26/50
# 500/500 - 19s - loss: 0.0339 - accuracy: 0.9965 - val_loss: 1.6919 - val_accuracy: 0.8810 - 19s/epoch - 38ms/step
# Epoch 27/50
# 500/500 - 19s - loss: 0.0325 - accuracy: 0.9975 - val_loss: 2.3201 - val_accuracy: 0.8571 - 19s/epoch - 38ms/step
# Epoch 28/50
# 500/500 - 19s - loss: 0.0148 - accuracy: 0.9980 - val_loss: 1.5374 - val_accuracy: 0.8571 - 19s/epoch - 38ms/step
# Epoch 29/50
# 500/500 - 19s - loss: 0.0431 - accuracy: 0.9970 - val_loss: 1.3065 - val_accuracy: 0.8810 - 19s/epoch - 38ms/step
# Epoch 30/50
# 500/500 - 19s - loss: 0.0276 - accuracy: 0.9970 - val_loss: 1.4345 - val_accuracy: 0.8810 - 19s/epoch - 38ms/step
# Epoch 31/50
# 500/500 - 19s - loss: 0.0289 - accuracy: 0.9950 - val_loss: 4.4128 - val_accuracy: 0.8333 - 19s/epoch - 38ms/step
# Epoch 32/50
# 500/500 - 19s - loss: 0.0073 - accuracy: 0.9975 - val_loss: 2.0548 - val_accuracy: 0.8810 - 19s/epoch - 38ms/step
# Epoch 33/50
# 500/500 - 19s - loss: 0.0282 - accuracy: 0.9960 - val_loss: 3.2002 - val_accuracy: 0.8333 - 19s/epoch - 38ms/step
# Epoch 34/50
# 500/500 - 19s - loss: 0.0267 - accuracy: 0.9980 - val_loss: 3.4913 - val_accuracy: 0.8095 - 19s/epoch - 38ms/step
# Epoch 35/50
# 500/500 - 19s - loss: 0.0526 - accuracy: 0.9965 - val_loss: 4.6855 - val_accuracy: 0.8095 - 19s/epoch - 38ms/step
# Epoch 36/50
# 500/500 - 19s - loss: 0.0333 - accuracy: 0.9985 - val_loss: 1.8223 - val_accuracy: 0.8810 - 19s/epoch - 38ms/step
# Epoch 37/50
# 500/500 - 19s - loss: 0.0343 - accuracy: 0.9965 - val_loss: 1.3901 - val_accuracy: 0.8571 - 19s/epoch - 38ms/step
# Epoch 38/50
# 500/500 - 19s - loss: 0.0240 - accuracy: 0.9965 - val_loss: 3.2867 - val_accuracy: 0.8333 - 19s/epoch - 38ms/step
# Epoch 39/50
# 500/500 - 19s - loss: 4.8271e-04 - accuracy: 0.9995 - val_loss: 1.8823 - val_accuracy: 0.8571 - 19s/epoch - 38ms/step
# Epoch 40/50
# 500/500 - 19s - loss: 1.2218e-04 - accuracy: 1.0000 - val_loss: 4.9291 - val_accuracy: 0.8810 - 19s/epoch - 38ms/step
# Epoch 41/50
# 500/500 - 19s - loss: 0.0265 - accuracy: 0.9985 - val_loss: 2.6588 - val_accuracy: 0.8571 - 19s/epoch - 38ms/step
# Epoch 42/50
# 500/500 - 19s - loss: 4.3351e-11 - accuracy: 1.0000 - val_loss: 3.2009 - val_accuracy: 0.8571 - 19s/epoch - 38ms/step
# Epoch 43/50
# 500/500 - 19s - loss: 0.0142 - accuracy: 0.9990 - val_loss: 2.2506 - val_accuracy: 0.8571 - 19s/epoch - 38ms/step
# Epoch 44/50
# 500/500 - 19s - loss: 0.0102 - accuracy: 0.9990 - val_loss: 2.6826 - val_accuracy: 0.8810 - 19s/epoch - 38ms/step
# Epoch 45/50
# 500/500 - 19s - loss: 0.0055 - accuracy: 0.9990 - val_loss: 2.9526 - val_accuracy: 0.8571 - 19s/epoch - 38ms/step
# Epoch 46/50
# 500/500 - 19s - loss: 3.0063e-09 - accuracy: 1.0000 - val_loss: 4.2667 - val_accuracy: 0.8095 - 19s/epoch - 38ms/step
# Epoch 47/50
# 500/500 - 19s - loss: 0.0045 - accuracy: 0.9985 - val_loss: 2.8037 - val_accuracy: 0.8810 - 19s/epoch - 38ms/step
# Epoch 48/50
# 500/500 - 19s - loss: 2.5541e-10 - accuracy: 1.0000 - val_loss: 2.4907 - val_accuracy: 0.8571 - 19s/epoch - 38ms/step
# Epoch 49/50
# 500/500 - 19s - loss: 1.1177e-09 - accuracy: 1.0000 - val_loss: 2.8299 - val_accuracy: 0.8571 - 19s/epoch - 38ms/step
# Epoch 50/50
# 500/500 - 19s - loss: 8.8937e-13 - accuracy: 1.0000 - val_loss: 2.7825 - val_accuracy: 0.8571 - 19s/epoch - 38ms/step
# 11/11 [==============================] - 1s 40ms/step - loss: 2.7825 - accuracy: 0.8571
# Epoch 1/50
# 500/500 - 20s - loss: 0.3871 - accuracy: 0.8490 - val_loss: 1.9150 - val_accuracy: 0.4762 - 20s/epoch - 41ms/step
# Epoch 2/50
# 500/500 - 19s - loss: 0.2198 - accuracy: 0.9210 - val_loss: 0.7944 - val_accuracy: 0.8333 - 19s/epoch - 38ms/step
# Epoch 3/50
# 500/500 - 19s - loss: 0.1466 - accuracy: 0.9410 - val_loss: 0.3081 - val_accuracy: 0.8810 - 19s/epoch - 38ms/step
# Epoch 4/50
# 500/500 - 19s - loss: 0.1192 - accuracy: 0.9630 - val_loss: 1.5808 - val_accuracy: 0.7619 - 19s/epoch - 38ms/step
# Epoch 5/50
# 500/500 - 19s - loss: 0.1118 - accuracy: 0.9655 - val_loss: 0.8177 - val_accuracy: 0.8333 - 19s/epoch - 39ms/step
# Epoch 6/50
# 500/500 - 19s - loss: 0.1030 - accuracy: 0.9740 - val_loss: 0.4728 - val_accuracy: 0.9286 - 19s/epoch - 38ms/step
# Epoch 7/50
# 500/500 - 19s - loss: 0.0755 - accuracy: 0.9830 - val_loss: 0.7719 - val_accuracy: 0.8810 - 19s/epoch - 39ms/step
# Epoch 8/50
# 500/500 - 19s - loss: 0.0671 - accuracy: 0.9840 - val_loss: 1.1824 - val_accuracy: 0.9048 - 19s/epoch - 39ms/step
# Epoch 9/50
# 500/500 - 19s - loss: 0.0785 - accuracy: 0.9835 - val_loss: 1.5707 - val_accuracy: 0.8333 - 19s/epoch - 39ms/step
# Epoch 10/50
# 500/500 - 19s - loss: 0.0784 - accuracy: 0.9855 - val_loss: 2.6724 - val_accuracy: 0.8095 - 19s/epoch - 39ms/step
# Epoch 11/50
# 500/500 - 19s - loss: 0.0507 - accuracy: 0.9870 - val_loss: 1.8913 - val_accuracy: 0.8333 - 19s/epoch - 39ms/step
# Epoch 12/50
# 500/500 - 19s - loss: 0.0548 - accuracy: 0.9925 - val_loss: 2.1427 - val_accuracy: 0.8571 - 19s/epoch - 39ms/step
# Epoch 13/50
# 500/500 - 19s - loss: 0.0567 - accuracy: 0.9900 - val_loss: 1.9415 - val_accuracy: 0.8333 - 19s/epoch - 39ms/step
# Epoch 14/50
# 500/500 - 19s - loss: 0.0410 - accuracy: 0.9920 - val_loss: 1.8844 - val_accuracy: 0.8571 - 19s/epoch - 39ms/step
# Epoch 15/50
# 500/500 - 19s - loss: 0.0416 - accuracy: 0.9940 - val_loss: 1.3779 - val_accuracy: 0.8571 - 19s/epoch - 39ms/step
# Epoch 16/50
# 500/500 - 19s - loss: 0.0345 - accuracy: 0.9950 - val_loss: 1.4966 - val_accuracy: 0.9048 - 19s/epoch - 39ms/step
# Epoch 17/50
# 500/500 - 19s - loss: 0.0343 - accuracy: 0.9950 - val_loss: 1.7040 - val_accuracy: 0.8571 - 19s/epoch - 39ms/step
# Epoch 18/50
# 500/500 - 19s - loss: 0.0736 - accuracy: 0.9915 - val_loss: 1.9404 - val_accuracy: 0.8333 - 19s/epoch - 39ms/step
# Epoch 19/50
# 500/500 - 19s - loss: 0.0268 - accuracy: 0.9975 - val_loss: 2.0732 - val_accuracy: 0.8571 - 19s/epoch - 39ms/step
# Epoch 20/50
# 500/500 - 20s - loss: 0.0249 - accuracy: 0.9980 - val_loss: 1.5009 - val_accuracy: 0.8333 - 20s/epoch - 39ms/step
# Epoch 21/50
# 500/500 - 20s - loss: 0.0576 - accuracy: 0.9970 - val_loss: 2.4242 - val_accuracy: 0.8810 - 20s/epoch - 39ms/step
# Epoch 22/50
# 500/500 - 19s - loss: 0.0362 - accuracy: 0.9950 - val_loss: 3.8735 - val_accuracy: 0.8095 - 19s/epoch - 39ms/step
# Epoch 23/50
# 500/500 - 20s - loss: 0.0139 - accuracy: 0.9970 - val_loss: 2.5333 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 24/50
# 500/500 - 20s - loss: 0.0271 - accuracy: 0.9970 - val_loss: 2.6108 - val_accuracy: 0.8333 - 20s/epoch - 39ms/step
# Epoch 25/50
# 500/500 - 19s - loss: 0.0545 - accuracy: 0.9950 - val_loss: 2.7966 - val_accuracy: 0.8571 - 19s/epoch - 39ms/step
# Epoch 26/50
# 500/500 - 20s - loss: 0.0276 - accuracy: 0.9975 - val_loss: 3.9241 - val_accuracy: 0.8571 - 20s/epoch - 39ms/step
# Epoch 27/50
# 500/500 - 20s - loss: 0.0336 - accuracy: 0.9970 - val_loss: 5.2536 - val_accuracy: 0.8333 - 20s/epoch - 39ms/step
# Epoch 28/50
# 500/500 - 20s - loss: 0.0582 - accuracy: 0.9935 - val_loss: 2.9681 - val_accuracy: 0.8333 - 20s/epoch - 39ms/step
# Epoch 29/50
# 500/500 - 20s - loss: 0.0208 - accuracy: 0.9985 - val_loss: 2.7688 - val_accuracy: 0.9048 - 20s/epoch - 39ms/step
# Epoch 30/50
# 500/500 - 20s - loss: 0.0086 - accuracy: 0.9985 - val_loss: 3.1577 - val_accuracy: 0.8571 - 20s/epoch - 39ms/step
# Epoch 31/50
# 500/500 - 20s - loss: 0.0142 - accuracy: 0.9990 - val_loss: 2.6891 - val_accuracy: 0.8333 - 20s/epoch - 39ms/step
# Epoch 32/50
# 500/500 - 20s - loss: 0.0515 - accuracy: 0.9965 - val_loss: 2.9366 - val_accuracy: 0.8571 - 20s/epoch - 39ms/step
# Epoch 33/50
# 500/500 - 20s - loss: 0.0060 - accuracy: 0.9980 - val_loss: 5.0197 - val_accuracy: 0.8571 - 20s/epoch - 39ms/step
# Epoch 34/50
# 500/500 - 20s - loss: 0.0699 - accuracy: 0.9950 - val_loss: 4.5476 - val_accuracy: 0.8571 - 20s/epoch - 39ms/step
# Epoch 35/50
# 500/500 - 20s - loss: 0.0344 - accuracy: 0.9945 - val_loss: 7.6840 - val_accuracy: 0.7857 - 20s/epoch - 39ms/step
# Epoch 36/50
# 500/500 - 20s - loss: 0.0094 - accuracy: 0.9990 - val_loss: 4.1793 - val_accuracy: 0.8810 - 20s/epoch - 40ms/step
# Epoch 37/50
# 500/500 - 20s - loss: 0.0120 - accuracy: 0.9975 - val_loss: 3.1238 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 38/50
# 500/500 - 20s - loss: 0.0444 - accuracy: 0.9965 - val_loss: 4.5026 - val_accuracy: 0.8571 - 20s/epoch - 39ms/step
# Epoch 39/50
# 500/500 - 19s - loss: 0.0142 - accuracy: 0.9995 - val_loss: 2.0119 - val_accuracy: 0.8571 - 19s/epoch - 39ms/step
# Epoch 40/50
# 500/500 - 19s - loss: 0.0113 - accuracy: 0.9990 - val_loss: 4.5755 - val_accuracy: 0.8810 - 19s/epoch - 39ms/step
# Epoch 41/50
# 500/500 - 19s - loss: 0.0267 - accuracy: 0.9995 - val_loss: 3.3625 - val_accuracy: 0.8571 - 19s/epoch - 39ms/step
# Epoch 42/50
# 500/500 - 19s - loss: 0.0188 - accuracy: 0.9985 - val_loss: 2.9838 - val_accuracy: 0.8571 - 19s/epoch - 39ms/step
# Epoch 43/50
# 500/500 - 19s - loss: 0.0203 - accuracy: 0.9985 - val_loss: 3.6784 - val_accuracy: 0.8810 - 19s/epoch - 39ms/step
# Epoch 44/50
# 500/500 - 19s - loss: 3.6465e-09 - accuracy: 1.0000 - val_loss: 3.7048 - val_accuracy: 0.8810 - 19s/epoch - 39ms/step
# Epoch 45/50
# 500/500 - 19s - loss: 1.4601e-11 - accuracy: 1.0000 - val_loss: 3.6204 - val_accuracy: 0.8571 - 19s/epoch - 39ms/step
# Epoch 46/50
# 500/500 - 19s - loss: 1.2431e-11 - accuracy: 1.0000 - val_loss: 3.6004 - val_accuracy: 0.8571 - 19s/epoch - 39ms/step
# Epoch 47/50
# 500/500 - 19s - loss: 1.4554e-11 - accuracy: 1.0000 - val_loss: 3.5854 - val_accuracy: 0.8571 - 19s/epoch - 39ms/step
# Epoch 48/50
# 500/500 - 20s - loss: 1.6468e-11 - accuracy: 1.0000 - val_loss: 3.5737 - val_accuracy: 0.8571 - 20s/epoch - 39ms/step
# Epoch 49/50
# 500/500 - 19s - loss: 1.7760e-11 - accuracy: 1.0000 - val_loss: 3.5638 - val_accuracy: 0.8571 - 19s/epoch - 39ms/step
# Epoch 50/50
# 500/500 - 19s - loss: 2.0603e-11 - accuracy: 1.0000 - val_loss: 3.5554 - val_accuracy: 0.8571 - 19s/epoch - 39ms/step
# 11/11 [==============================] - 0s 36ms/step - loss: 3.5554 - accuracy: 0.8571
# Epoch 1/50
# 500/500 - 20s - loss: 0.4015 - accuracy: 0.8485 - val_loss: 0.2899 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 2/50
# 500/500 - 19s - loss: 0.2277 - accuracy: 0.9140 - val_loss: 1.0240 - val_accuracy: 0.7619 - 19s/epoch - 38ms/step
# Epoch 3/50
# 500/500 - 19s - loss: 0.1696 - accuracy: 0.9490 - val_loss: 0.7776 - val_accuracy: 0.7857 - 19s/epoch - 38ms/step
# Epoch 4/50
# 500/500 - 20s - loss: 0.1422 - accuracy: 0.9525 - val_loss: 0.3162 - val_accuracy: 0.9048 - 20s/epoch - 39ms/step
# Epoch 5/50
# 500/500 - 19s - loss: 0.1092 - accuracy: 0.9680 - val_loss: 0.6800 - val_accuracy: 0.8333 - 19s/epoch - 39ms/step
# Epoch 6/50
# 500/500 - 19s - loss: 0.1025 - accuracy: 0.9720 - val_loss: 1.2046 - val_accuracy: 0.8571 - 19s/epoch - 39ms/step
# Epoch 7/50
# 500/500 - 19s - loss: 0.0840 - accuracy: 0.9780 - val_loss: 4.1044 - val_accuracy: 0.7381 - 19s/epoch - 39ms/step
# Epoch 8/50
# 500/500 - 20s - loss: 0.0972 - accuracy: 0.9795 - val_loss: 2.1344 - val_accuracy: 0.8571 - 20s/epoch - 39ms/step
# Epoch 9/50
# 500/500 - 20s - loss: 0.0988 - accuracy: 0.9805 - val_loss: 1.4441 - val_accuracy: 0.8333 - 20s/epoch - 39ms/step
# Epoch 10/50
# 500/500 - 20s - loss: 0.0805 - accuracy: 0.9845 - val_loss: 1.5433 - val_accuracy: 0.9048 - 20s/epoch - 39ms/step
# Epoch 11/50
# 500/500 - 20s - loss: 0.0764 - accuracy: 0.9905 - val_loss: 2.8559 - val_accuracy: 0.8571 - 20s/epoch - 39ms/step
# Epoch 12/50
# 500/500 - 20s - loss: 0.0847 - accuracy: 0.9890 - val_loss: 2.9591 - val_accuracy: 0.8333 - 20s/epoch - 39ms/step
# Epoch 13/50
# 500/500 - 20s - loss: 0.0650 - accuracy: 0.9920 - val_loss: 1.6402 - val_accuracy: 0.8810 - 20s/epoch - 39ms/step
# Epoch 14/50
# 500/500 - 20s - loss: 0.0830 - accuracy: 0.9855 - val_loss: 4.4393 - val_accuracy: 0.7619 - 20s/epoch - 39ms/step
# Epoch 15/50
# 500/500 - 20s - loss: 0.0767 - accuracy: 0.9925 - val_loss: 2.5281 - val_accuracy: 0.8095 - 20s/epoch - 39ms/step
# Epoch 16/50
# 500/500 - 20s - loss: 0.0691 - accuracy: 0.9910 - val_loss: 2.8250 - val_accuracy: 0.8810 - 20s/epoch - 39ms/step
# Epoch 17/50
# 500/500 - 20s - loss: 0.0454 - accuracy: 0.9925 - val_loss: 3.7113 - val_accuracy: 0.8333 - 20s/epoch - 39ms/step
# Epoch 18/50
# 500/500 - 20s - loss: 0.0347 - accuracy: 0.9930 - val_loss: 3.6061 - val_accuracy: 0.8810 - 20s/epoch - 39ms/step
# Epoch 19/50
# 500/500 - 20s - loss: 0.0765 - accuracy: 0.9930 - val_loss: 1.3012 - val_accuracy: 0.8571 - 20s/epoch - 39ms/step
# Epoch 20/50
# 500/500 - 20s - loss: 0.0412 - accuracy: 0.9945 - val_loss: 2.7801 - val_accuracy: 0.8810 - 20s/epoch - 39ms/step
# Epoch 21/50
# 500/500 - 20s - loss: 0.0144 - accuracy: 0.9970 - val_loss: 4.5591 - val_accuracy: 0.8571 - 20s/epoch - 39ms/step
# Epoch 22/50
# 500/500 - 20s - loss: 0.0840 - accuracy: 0.9940 - val_loss: 1.6687 - val_accuracy: 0.8333 - 20s/epoch - 40ms/step
# Epoch 23/50
# 500/500 - 20s - loss: 0.0368 - accuracy: 0.9955 - val_loss: 3.1973 - val_accuracy: 0.8571 - 20s/epoch - 39ms/step
# Epoch 24/50
# 500/500 - 20s - loss: 0.0367 - accuracy: 0.9945 - val_loss: 2.9760 - val_accuracy: 0.8333 - 20s/epoch - 40ms/step
# Epoch 25/50
# 500/500 - 20s - loss: 0.0692 - accuracy: 0.9950 - val_loss: 4.2971 - val_accuracy: 0.8095 - 20s/epoch - 39ms/step
# Epoch 26/50
# 500/500 - 20s - loss: 0.0535 - accuracy: 0.9930 - val_loss: 5.6575 - val_accuracy: 0.7619 - 20s/epoch - 39ms/step
# Epoch 27/50
# 500/500 - 20s - loss: 0.0458 - accuracy: 0.9935 - val_loss: 2.2890 - val_accuracy: 0.8571 - 20s/epoch - 39ms/step
# Epoch 28/50
# 500/500 - 19s - loss: 0.0366 - accuracy: 0.9930 - val_loss: 3.5777 - val_accuracy: 0.8571 - 19s/epoch - 39ms/step
# Epoch 29/50
# 500/500 - 20s - loss: 0.0555 - accuracy: 0.9945 - val_loss: 2.4868 - val_accuracy: 0.8571 - 20s/epoch - 39ms/step
# Epoch 30/50
# 500/500 - 20s - loss: 0.0478 - accuracy: 0.9955 - val_loss: 9.1348 - val_accuracy: 0.7857 - 20s/epoch - 39ms/step
# Epoch 31/50
# 500/500 - 20s - loss: 0.0215 - accuracy: 0.9985 - val_loss: 5.3158 - val_accuracy: 0.8333 - 20s/epoch - 40ms/step
# Epoch 32/50
# 500/500 - 20s - loss: 0.0139 - accuracy: 0.9970 - val_loss: 4.5871 - val_accuracy: 0.8333 - 20s/epoch - 39ms/step
# Epoch 33/50
# 500/500 - 20s - loss: 0.0250 - accuracy: 0.9960 - val_loss: 2.7636 - val_accuracy: 0.8810 - 20s/epoch - 39ms/step
# Epoch 34/50
# 500/500 - 20s - loss: 0.0210 - accuracy: 0.9965 - val_loss: 2.2775 - val_accuracy: 0.8571 - 20s/epoch - 39ms/step
# Epoch 35/50
# 500/500 - 20s - loss: 0.0398 - accuracy: 0.9975 - val_loss: 5.2387 - val_accuracy: 0.8095 - 20s/epoch - 39ms/step
# Epoch 36/50
# 500/500 - 20s - loss: 0.0300 - accuracy: 0.9955 - val_loss: 4.5041 - val_accuracy: 0.8333 - 20s/epoch - 39ms/step
# Epoch 37/50
# 500/500 - 20s - loss: 0.0469 - accuracy: 0.9965 - val_loss: 5.9415 - val_accuracy: 0.8333 - 20s/epoch - 39ms/step
# Epoch 38/50
# 500/500 - 20s - loss: 0.0357 - accuracy: 0.9960 - val_loss: 6.8622 - val_accuracy: 0.8333 - 20s/epoch - 39ms/step
# Epoch 39/50
# 500/500 - 20s - loss: 0.0120 - accuracy: 0.9975 - val_loss: 3.9657 - val_accuracy: 0.8333 - 20s/epoch - 39ms/step
# Epoch 40/50
# 500/500 - 20s - loss: 0.0254 - accuracy: 0.9980 - val_loss: 4.4234 - val_accuracy: 0.8333 - 20s/epoch - 40ms/step
# Epoch 41/50
# 500/500 - 20s - loss: 0.0306 - accuracy: 0.9980 - val_loss: 4.1164 - val_accuracy: 0.8810 - 20s/epoch - 40ms/step
# Epoch 42/50
# 500/500 - 19s - loss: 0.0156 - accuracy: 0.9990 - val_loss: 6.4169 - val_accuracy: 0.8810 - 19s/epoch - 39ms/step
# Epoch 43/50
# 500/500 - 19s - loss: 0.0395 - accuracy: 0.9970 - val_loss: 5.6177 - val_accuracy: 0.8571 - 19s/epoch - 39ms/step
# Epoch 44/50
# 500/500 - 19s - loss: 0.0234 - accuracy: 0.9965 - val_loss: 6.9403 - val_accuracy: 0.8333 - 19s/epoch - 39ms/step
# Epoch 45/50
# 500/500 - 20s - loss: 0.0263 - accuracy: 0.9965 - val_loss: 10.1374 - val_accuracy: 0.8095 - 20s/epoch - 39ms/step
# Epoch 46/50
# 500/500 - 20s - loss: 0.0280 - accuracy: 0.9970 - val_loss: 13.8037 - val_accuracy: 0.7381 - 20s/epoch - 39ms/step
# Epoch 47/50
# 500/500 - 20s - loss: 0.0348 - accuracy: 0.9980 - val_loss: 4.2053 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 48/50
# 500/500 - 20s - loss: 0.0152 - accuracy: 0.9990 - val_loss: 8.4245 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 49/50
# 500/500 - 19s - loss: 0.0263 - accuracy: 0.9980 - val_loss: 4.5101 - val_accuracy: 0.8571 - 19s/epoch - 39ms/step
# Epoch 50/50
# 500/500 - 19s - loss: 0.0095 - accuracy: 0.9980 - val_loss: 4.9502 - val_accuracy: 0.8333 - 19s/epoch - 39ms/step
# 11/11 [==============================] - 0s 36ms/step - loss: 4.9502 - accuracy: 0.8333
# Epoch 1/50
# 500/500 - 21s - loss: 0.3708 - accuracy: 0.8505 - val_loss: 1.1187 - val_accuracy: 0.6190 - 21s/epoch - 42ms/step
# Epoch 2/50
# 500/500 - 19s - loss: 0.2098 - accuracy: 0.9225 - val_loss: 0.6363 - val_accuracy: 0.8095 - 19s/epoch - 39ms/step
# Epoch 3/50
# 500/500 - 20s - loss: 0.1556 - accuracy: 0.9535 - val_loss: 0.3454 - val_accuracy: 0.8095 - 20s/epoch - 39ms/step
# Epoch 4/50
# 500/500 - 20s - loss: 0.1300 - accuracy: 0.9600 - val_loss: 0.4416 - val_accuracy: 0.9048 - 20s/epoch - 39ms/step
# Epoch 5/50
# 500/500 - 20s - loss: 0.1140 - accuracy: 0.9685 - val_loss: 0.3892 - val_accuracy: 0.8571 - 20s/epoch - 39ms/step
# Epoch 6/50
# 500/500 - 20s - loss: 0.0952 - accuracy: 0.9765 - val_loss: 0.4909 - val_accuracy: 0.8810 - 20s/epoch - 40ms/step
# Epoch 7/50
# 500/500 - 20s - loss: 0.0854 - accuracy: 0.9770 - val_loss: 1.0740 - val_accuracy: 0.8333 - 20s/epoch - 40ms/step
# Epoch 8/50
# 500/500 - 20s - loss: 0.0712 - accuracy: 0.9820 - val_loss: 1.1929 - val_accuracy: 0.8810 - 20s/epoch - 40ms/step
# Epoch 9/50
# 500/500 - 20s - loss: 0.0816 - accuracy: 0.9835 - val_loss: 2.6383 - val_accuracy: 0.6667 - 20s/epoch - 39ms/step
# Epoch 10/50
# 500/500 - 20s - loss: 0.0621 - accuracy: 0.9840 - val_loss: 0.7535 - val_accuracy: 0.8571 - 20s/epoch - 39ms/step
# Epoch 11/50
# 500/500 - 20s - loss: 0.0511 - accuracy: 0.9900 - val_loss: 0.6427 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 12/50
# 500/500 - 20s - loss: 0.0747 - accuracy: 0.9875 - val_loss: 1.0755 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 13/50
# 500/500 - 20s - loss: 0.0561 - accuracy: 0.9895 - val_loss: 1.0507 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 14/50
# 500/500 - 20s - loss: 0.0381 - accuracy: 0.9945 - val_loss: 2.3842 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 15/50
# 500/500 - 20s - loss: 0.0759 - accuracy: 0.9915 - val_loss: 2.7125 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 16/50
# 500/500 - 20s - loss: 0.0440 - accuracy: 0.9930 - val_loss: 1.3160 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 17/50
# 500/500 - 20s - loss: 0.0454 - accuracy: 0.9940 - val_loss: 0.7600 - val_accuracy: 0.9048 - 20s/epoch - 39ms/step
# Epoch 18/50
# 500/500 - 20s - loss: 0.0396 - accuracy: 0.9950 - val_loss: 1.2505 - val_accuracy: 0.8810 - 20s/epoch - 39ms/step
# Epoch 19/50
# 500/500 - 20s - loss: 0.0322 - accuracy: 0.9950 - val_loss: 1.7652 - val_accuracy: 0.8810 - 20s/epoch - 40ms/step
# Epoch 20/50
# 500/500 - 20s - loss: 0.0386 - accuracy: 0.9950 - val_loss: 1.9212 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 21/50
# 500/500 - 20s - loss: 0.0421 - accuracy: 0.9955 - val_loss: 1.5278 - val_accuracy: 0.9048 - 20s/epoch - 40ms/step
# Epoch 22/50
# 500/500 - 20s - loss: 0.0303 - accuracy: 0.9960 - val_loss: 1.0900 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 23/50
# 500/500 - 20s - loss: 0.0083 - accuracy: 0.9980 - val_loss: 1.9190 - val_accuracy: 0.8810 - 20s/epoch - 39ms/step
# Epoch 24/50
# 500/500 - 20s - loss: 0.0123 - accuracy: 0.9975 - val_loss: 2.9358 - val_accuracy: 0.8333 - 20s/epoch - 39ms/step
# Epoch 25/50
# 500/500 - 20s - loss: 0.0331 - accuracy: 0.9955 - val_loss: 1.4515 - val_accuracy: 0.8810 - 20s/epoch - 40ms/step
# Epoch 26/50
# 500/500 - 20s - loss: 0.0346 - accuracy: 0.9975 - val_loss: 1.5976 - val_accuracy: 0.9048 - 20s/epoch - 39ms/step
# Epoch 27/50
# 500/500 - 20s - loss: 0.0461 - accuracy: 0.9955 - val_loss: 1.9395 - val_accuracy: 0.9286 - 20s/epoch - 39ms/step
# Epoch 28/50
# 500/500 - 20s - loss: 0.0524 - accuracy: 0.9945 - val_loss: 3.1143 - val_accuracy: 0.9048 - 20s/epoch - 40ms/step
# Epoch 29/50
# 500/500 - 20s - loss: 0.0216 - accuracy: 0.9990 - val_loss: 3.2859 - val_accuracy: 0.8810 - 20s/epoch - 40ms/step
# Epoch 30/50
# 500/500 - 20s - loss: 0.0088 - accuracy: 0.9990 - val_loss: 1.6665 - val_accuracy: 0.9048 - 20s/epoch - 40ms/step
# Epoch 31/50
# 500/500 - 20s - loss: 0.0202 - accuracy: 0.9980 - val_loss: 2.0969 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 32/50
# 500/500 - 20s - loss: 0.0207 - accuracy: 0.9975 - val_loss: 1.5777 - val_accuracy: 0.8810 - 20s/epoch - 40ms/step
# Epoch 33/50
# 500/500 - 20s - loss: 0.0189 - accuracy: 0.9990 - val_loss: 2.2678 - val_accuracy: 0.8810 - 20s/epoch - 39ms/step
# Epoch 34/50
# 500/500 - 20s - loss: 0.0198 - accuracy: 0.9970 - val_loss: 2.4995 - val_accuracy: 0.8571 - 20s/epoch - 39ms/step
# Epoch 35/50
# 500/500 - 20s - loss: 0.0370 - accuracy: 0.9975 - val_loss: 3.3940 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 36/50
# 500/500 - 20s - loss: 0.0392 - accuracy: 0.9960 - val_loss: 2.6662 - val_accuracy: 0.8810 - 20s/epoch - 40ms/step
# Epoch 37/50
# 500/500 - 20s - loss: 0.0434 - accuracy: 0.9960 - val_loss: 3.8170 - val_accuracy: 0.8810 - 20s/epoch - 40ms/step
# Epoch 38/50
# 500/500 - 20s - loss: 0.0273 - accuracy: 0.9965 - val_loss: 1.8263 - val_accuracy: 0.8571 - 20s/epoch - 39ms/step
# Epoch 39/50
# 500/500 - 20s - loss: 0.0371 - accuracy: 0.9990 - val_loss: 1.7543 - val_accuracy: 0.8810 - 20s/epoch - 39ms/step
# Epoch 40/50
# 500/500 - 20s - loss: 0.0310 - accuracy: 0.9945 - val_loss: 4.0031 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 41/50
# 500/500 - 20s - loss: 0.0580 - accuracy: 0.9965 - val_loss: 3.6499 - val_accuracy: 0.8810 - 20s/epoch - 40ms/step
# Epoch 42/50
# 500/500 - 20s - loss: 0.0119 - accuracy: 0.9990 - val_loss: 4.9442 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 43/50
# 500/500 - 20s - loss: 0.0133 - accuracy: 0.9990 - val_loss: 2.0567 - val_accuracy: 0.8810 - 20s/epoch - 40ms/step
# Epoch 44/50
# 500/500 - 20s - loss: 0.0177 - accuracy: 0.9985 - val_loss: 1.9584 - val_accuracy: 0.9286 - 20s/epoch - 39ms/step
# Epoch 45/50
# 500/500 - 20s - loss: 0.0161 - accuracy: 0.9985 - val_loss: 3.8084 - val_accuracy: 0.8810 - 20s/epoch - 39ms/step
# Epoch 46/50
# 500/500 - 20s - loss: 0.0122 - accuracy: 0.9985 - val_loss: 2.8236 - val_accuracy: 0.9286 - 20s/epoch - 40ms/step
# Epoch 47/50
# 500/500 - 20s - loss: 4.0650e-05 - accuracy: 1.0000 - val_loss: 4.1745 - val_accuracy: 0.8810 - 20s/epoch - 40ms/step
# Epoch 48/50
# 500/500 - 20s - loss: 0.0209 - accuracy: 0.9975 - val_loss: 3.2612 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 49/50
# 500/500 - 20s - loss: 8.5054e-04 - accuracy: 0.9995 - val_loss: 2.5650 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 50/50
# 500/500 - 20s - loss: 0.0746 - accuracy: 0.9955 - val_loss: 4.0662 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# 11/11 [==============================] - 1s 41ms/step - loss: 4.0662 - accuracy: 0.8571
# WARNING:tensorflow:5 out of the last 10 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8e2006c170> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1/50
# 500/500 - 21s - loss: 0.3663 - accuracy: 0.8535 - val_loss: 0.6527 - val_accuracy: 0.8095 - 21s/epoch - 42ms/step
# Epoch 2/50
# 500/500 - 20s - loss: 0.2062 - accuracy: 0.9180 - val_loss: 0.7323 - val_accuracy: 0.8333 - 20s/epoch - 40ms/step
# Epoch 3/50
# 500/500 - 20s - loss: 0.1420 - accuracy: 0.9515 - val_loss: 1.4730 - val_accuracy: 0.8095 - 20s/epoch - 40ms/step
# Epoch 4/50
# 500/500 - 20s - loss: 0.1282 - accuracy: 0.9630 - val_loss: 0.6550 - val_accuracy: 0.8333 - 20s/epoch - 40ms/step
# Epoch 5/50
# 500/500 - 20s - loss: 0.1212 - accuracy: 0.9640 - val_loss: 0.5313 - val_accuracy: 0.8571 - 20s/epoch - 39ms/step
# Epoch 6/50
# 500/500 - 20s - loss: 0.1007 - accuracy: 0.9780 - val_loss: 0.6482 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 7/50
# 500/500 - 20s - loss: 0.0836 - accuracy: 0.9780 - val_loss: 0.6515 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 8/50
# 500/500 - 20s - loss: 0.0856 - accuracy: 0.9785 - val_loss: 2.2935 - val_accuracy: 0.8095 - 20s/epoch - 40ms/step
# Epoch 9/50
# 500/500 - 20s - loss: 0.0600 - accuracy: 0.9865 - val_loss: 0.6750 - val_accuracy: 0.8333 - 20s/epoch - 40ms/step
# Epoch 10/50
# 500/500 - 20s - loss: 0.0667 - accuracy: 0.9875 - val_loss: 1.2567 - val_accuracy: 0.8333 - 20s/epoch - 40ms/step
# Epoch 11/50
# 500/500 - 20s - loss: 0.0529 - accuracy: 0.9885 - val_loss: 1.2335 - val_accuracy: 0.8095 - 20s/epoch - 40ms/step
# Epoch 12/50
# 500/500 - 20s - loss: 0.0587 - accuracy: 0.9900 - val_loss: 1.4620 - val_accuracy: 0.8333 - 20s/epoch - 39ms/step
# Epoch 13/50
# 500/500 - 20s - loss: 0.0650 - accuracy: 0.9910 - val_loss: 1.3171 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 14/50
# 500/500 - 20s - loss: 0.0328 - accuracy: 0.9945 - val_loss: 1.3465 - val_accuracy: 0.7857 - 20s/epoch - 40ms/step
# Epoch 15/50
# 500/500 - 20s - loss: 0.0411 - accuracy: 0.9935 - val_loss: 1.9952 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 16/50
# 500/500 - 20s - loss: 0.0448 - accuracy: 0.9935 - val_loss: 1.4458 - val_accuracy: 0.8571 - 20s/epoch - 41ms/step
# Epoch 17/50
# 500/500 - 20s - loss: 0.0561 - accuracy: 0.9955 - val_loss: 2.0746 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 18/50
# 500/500 - 20s - loss: 0.0563 - accuracy: 0.9955 - val_loss: 1.2052 - val_accuracy: 0.8810 - 20s/epoch - 40ms/step
# Epoch 19/50
# 500/500 - 20s - loss: 0.0147 - accuracy: 0.9970 - val_loss: 1.6668 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 20/50
# 500/500 - 20s - loss: 0.0129 - accuracy: 0.9980 - val_loss: 6.2710 - val_accuracy: 0.8095 - 20s/epoch - 41ms/step
# Epoch 21/50
# 500/500 - 20s - loss: 0.0175 - accuracy: 0.9955 - val_loss: 1.4494 - val_accuracy: 0.8095 - 20s/epoch - 40ms/step
# Epoch 22/50
# 500/500 - 20s - loss: 0.0421 - accuracy: 0.9975 - val_loss: 4.2353 - val_accuracy: 0.8333 - 20s/epoch - 40ms/step
# Epoch 23/50
# 500/500 - 20s - loss: 0.0199 - accuracy: 0.9965 - val_loss: 2.2132 - val_accuracy: 0.8810 - 20s/epoch - 40ms/step
# Epoch 24/50
# 500/500 - 20s - loss: 0.0051 - accuracy: 0.9985 - val_loss: 2.1113 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 25/50
# 500/500 - 20s - loss: 0.0267 - accuracy: 0.9980 - val_loss: 4.5849 - val_accuracy: 0.8333 - 20s/epoch - 40ms/step
# Epoch 26/50
# 500/500 - 20s - loss: 0.0551 - accuracy: 0.9945 - val_loss: 3.9124 - val_accuracy: 0.8333 - 20s/epoch - 40ms/step
# Epoch 27/50
# 500/500 - 20s - loss: 0.0207 - accuracy: 0.9970 - val_loss: 4.1211 - val_accuracy: 0.8333 - 20s/epoch - 40ms/step
# Epoch 28/50
# 500/500 - 20s - loss: 0.0345 - accuracy: 0.9955 - val_loss: 4.7146 - val_accuracy: 0.8095 - 20s/epoch - 40ms/step
# Epoch 29/50
# 500/500 - 20s - loss: 0.0103 - accuracy: 0.9980 - val_loss: 5.1700 - val_accuracy: 0.8333 - 20s/epoch - 40ms/step
# Epoch 30/50
# 500/500 - 20s - loss: 0.0196 - accuracy: 0.9960 - val_loss: 12.8423 - val_accuracy: 0.7143 - 20s/epoch - 40ms/step
# Epoch 31/50
# 500/500 - 20s - loss: 0.0340 - accuracy: 0.9955 - val_loss: 2.2026 - val_accuracy: 0.8571 - 20s/epoch - 39ms/step
# Epoch 32/50
# 500/500 - 20s - loss: 0.0107 - accuracy: 0.9975 - val_loss: 3.8603 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 33/50
# 500/500 - 20s - loss: 0.0075 - accuracy: 0.9980 - val_loss: 5.9538 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 34/50
# 500/500 - 20s - loss: 0.0340 - accuracy: 0.9980 - val_loss: 5.3943 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# Epoch 35/50
# 500/500 - 20s - loss: 0.0144 - accuracy: 0.9980 - val_loss: 4.0501 - val_accuracy: 0.8095 - 20s/epoch - 40ms/step
# Epoch 36/50
# 500/500 - 20s - loss: 0.0213 - accuracy: 0.9975 - val_loss: 3.3908 - val_accuracy: 0.8095 - 20s/epoch - 40ms/step
# Epoch 37/50
# 500/500 - 20s - loss: 0.0160 - accuracy: 0.9995 - val_loss: 4.6540 - val_accuracy: 0.8095 - 20s/epoch - 40ms/step
# Epoch 38/50
# 500/500 - 20s - loss: 0.0061 - accuracy: 0.9995 - val_loss: 4.5737 - val_accuracy: 0.8333 - 20s/epoch - 40ms/step
# Epoch 39/50
# 500/500 - 20s - loss: 0.0077 - accuracy: 0.9985 - val_loss: 2.3698 - val_accuracy: 0.8333 - 20s/epoch - 40ms/step
# Epoch 40/50
# 500/500 - 20s - loss: 0.0094 - accuracy: 0.9995 - val_loss: 4.6604 - val_accuracy: 0.8333 - 20s/epoch - 40ms/step
# Epoch 41/50
# 500/500 - 20s - loss: 0.0041 - accuracy: 0.9990 - val_loss: 3.5355 - val_accuracy: 0.8810 - 20s/epoch - 40ms/step
# Epoch 42/50
# 500/500 - 20s - loss: 0.0217 - accuracy: 0.9990 - val_loss: 3.9833 - val_accuracy: 0.8571 - 20s/epoch - 39ms/step
# Epoch 43/50
# 500/500 - 20s - loss: 0.0048 - accuracy: 0.9990 - val_loss: 4.5832 - val_accuracy: 0.8333 - 20s/epoch - 40ms/step
# Epoch 44/50
# 500/500 - 20s - loss: 0.0162 - accuracy: 0.9985 - val_loss: 3.7752 - val_accuracy: 0.8333 - 20s/epoch - 40ms/step
# Epoch 45/50
# 500/500 - 20s - loss: 0.0115 - accuracy: 0.9995 - val_loss: 5.3822 - val_accuracy: 0.8333 - 20s/epoch - 39ms/step
# Epoch 46/50
# 500/500 - 20s - loss: 0.0114 - accuracy: 0.9985 - val_loss: 4.7250 - val_accuracy: 0.9048 - 20s/epoch - 40ms/step
# Epoch 47/50
# 500/500 - 20s - loss: 5.0921e-07 - accuracy: 1.0000 - val_loss: 3.2662 - val_accuracy: 0.8333 - 20s/epoch - 40ms/step
# Epoch 48/50
# 500/500 - 20s - loss: 3.7504e-08 - accuracy: 1.0000 - val_loss: 13.5914 - val_accuracy: 0.7619 - 20s/epoch - 40ms/step
# Epoch 49/50
# 500/500 - 20s - loss: 0.0179 - accuracy: 0.9995 - val_loss: 5.3565 - val_accuracy: 0.8333 - 20s/epoch - 40ms/step
# Epoch 50/50
# 500/500 - 20s - loss: 0.0161 - accuracy: 0.9985 - val_loss: 3.1421 - val_accuracy: 0.8571 - 20s/epoch - 40ms/step
# 11/11 [==============================] - 0s 35ms/step - loss: 3.1421 - accuracy: 0.8571
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8e72dfc290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:26: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.median(level=1) should use df.groupby(level=1).median().
#                    0          1  accuracy  macro avg  weighted avg  pos
# precision   0.935731   0.776986  0.852381   0.856358      0.867697  2.0
# recall      0.800000   0.922222  0.852381   0.861111      0.852381  2.0
# f1-score    0.861009   0.842012  0.852381   0.851510      0.852867  2.0
# support    24.000000  18.000000  0.852381  42.000000     42.000000  2.0

# %%
cr_list = []
cm_list = []
# callbacks = [earlystopper]
# callbacks = [model_checkpoint_callback]
callbacks = []
for i in range(5):
    model.get_model()
    opt = tf.keras.optimizers.RMSprop(learning_rate=configs['fine_tune_learning_rate'])
    model.model.compile(optimizer=opt,
                loss=configs['loss_fn'],
                metrics=configs['metrics'])
    # Train

    model.fine_tune(callbacks=callbacks, verbose=2, wb=True)

    # model.model.summary()
    cm_, cr_ = crcm(model, X_val, y_val, p=False)
    cm_list.append(cm_)
    cr_['pos'] = {'precision': i,
  'recall': i,
  'f1-score': i,
  'support': i}
    if i > 0:
        df = df.append(pd.DataFrame.from_dict(cr_))
    else:
        df = pd.DataFrame.from_dict(cr_)
df.mean(level=0)
# Out:
# Epoch 1/10
# 500/500 - 20s - loss: 0.6173 - accuracy: 0.6845 - val_loss: 0.6892 - val_accuracy: 0.5952 - 20s/epoch - 40ms/step
# Epoch 2/10
# 500/500 - 19s - loss: 0.5106 - accuracy: 0.7505 - val_loss: 0.6056 - val_accuracy: 0.6667 - 19s/epoch - 38ms/step
# Epoch 3/10
# 500/500 - 19s - loss: 0.4473 - accuracy: 0.7920 - val_loss: 0.5534 - val_accuracy: 0.6905 - 19s/epoch - 38ms/step
# Epoch 4/10
# 500/500 - 19s - loss: 0.4034 - accuracy: 0.8170 - val_loss: 0.4810 - val_accuracy: 0.7381 - 19s/epoch - 38ms/step
# Epoch 5/10
# 500/500 - 19s - loss: 0.3657 - accuracy: 0.8395 - val_loss: 0.4889 - val_accuracy: 0.7381 - 19s/epoch - 38ms/step
# Epoch 6/10
# 500/500 - 19s - loss: 0.3426 - accuracy: 0.8480 - val_loss: 0.4905 - val_accuracy: 0.7857 - 19s/epoch - 38ms/step
# Epoch 7/10
# 500/500 - 19s - loss: 0.3163 - accuracy: 0.8660 - val_loss: 0.4991 - val_accuracy: 0.7619 - 19s/epoch - 38ms/step
# Epoch 8/10
# 500/500 - 19s - loss: 0.3016 - accuracy: 0.8670 - val_loss: 0.4545 - val_accuracy: 0.8095 - 19s/epoch - 38ms/step
# Epoch 9/10
# 500/500 - 19s - loss: 0.2803 - accuracy: 0.8830 - val_loss: 0.4475 - val_accuracy: 0.8095 - 19s/epoch - 38ms/step
# Epoch 10/10
# 500/500 - 19s - loss: 0.2616 - accuracy: 0.8900 - val_loss: 0.4436 - val_accuracy: 0.8095 - 19s/epoch - 38ms/step
# 11/11 [==============================] - 0s 35ms/step - loss: 0.4436 - accuracy: 0.8095
# Epoch 1/10
# 500/500 - 20s - loss: 1.4810 - accuracy: 0.4785 - val_loss: 0.5448 - val_accuracy: 0.7143 - 20s/epoch - 40ms/step
# Epoch 2/10
# 500/500 - 19s - loss: 0.4933 - accuracy: 0.7815 - val_loss: 0.5321 - val_accuracy: 0.6905 - 19s/epoch - 38ms/step
# Epoch 3/10
# 500/500 - 19s - loss: 0.4329 - accuracy: 0.8125 - val_loss: 0.5231 - val_accuracy: 0.7381 - 19s/epoch - 38ms/step
# Epoch 4/10
# 500/500 - 19s - loss: 0.3989 - accuracy: 0.8330 - val_loss: 0.5174 - val_accuracy: 0.7381 - 19s/epoch - 39ms/step
# Epoch 5/10
# 500/500 - 19s - loss: 0.3714 - accuracy: 0.8515 - val_loss: 0.5208 - val_accuracy: 0.7381 - 19s/epoch - 38ms/step
# Epoch 6/10
# 500/500 - 19s - loss: 0.3464 - accuracy: 0.8650 - val_loss: 0.5142 - val_accuracy: 0.7381 - 19s/epoch - 38ms/step
# Epoch 7/10
# 500/500 - 19s - loss: 0.3281 - accuracy: 0.8725 - val_loss: 0.5042 - val_accuracy: 0.7619 - 19s/epoch - 39ms/step
# Epoch 8/10
# 500/500 - 19s - loss: 0.3161 - accuracy: 0.8775 - val_loss: 0.4714 - val_accuracy: 0.7619 - 19s/epoch - 39ms/step
# Epoch 9/10
# 500/500 - 19s - loss: 0.2958 - accuracy: 0.8870 - val_loss: 0.5076 - val_accuracy: 0.7619 - 19s/epoch - 39ms/step
# Epoch 10/10
# 500/500 - 20s - loss: 0.2843 - accuracy: 0.8910 - val_loss: 0.4701 - val_accuracy: 0.8095 - 20s/epoch - 39ms/step
# 11/11 [==============================] - 0s 35ms/step - loss: 0.4701 - accuracy: 0.8095
# Epoch 1/10
# 500/500 - 20s - loss: 0.6452 - accuracy: 0.6845 - val_loss: 0.6452 - val_accuracy: 0.5952 - 20s/epoch - 40ms/step
# Epoch 2/10
# 500/500 - 19s - loss: 0.5588 - accuracy: 0.7240 - val_loss: 0.5775 - val_accuracy: 0.6429 - 19s/epoch - 38ms/step
# Epoch 3/10
# 500/500 - 19s - loss: 0.4854 - accuracy: 0.7590 - val_loss: 0.5770 - val_accuracy: 0.6905 - 19s/epoch - 38ms/step
# Epoch 4/10
# 500/500 - 19s - loss: 0.4341 - accuracy: 0.8050 - val_loss: 0.5672 - val_accuracy: 0.6905 - 19s/epoch - 39ms/step
# Epoch 5/10
# 500/500 - 19s - loss: 0.3947 - accuracy: 0.8155 - val_loss: 0.5925 - val_accuracy: 0.6429 - 19s/epoch - 39ms/step
# Epoch 6/10
# 500/500 - 19s - loss: 0.3682 - accuracy: 0.8445 - val_loss: 0.5560 - val_accuracy: 0.6667 - 19s/epoch - 39ms/step
# Epoch 7/10
# 500/500 - 19s - loss: 0.3497 - accuracy: 0.8455 - val_loss: 0.5116 - val_accuracy: 0.6905 - 19s/epoch - 39ms/step
# Epoch 8/10
# 500/500 - 20s - loss: 0.3209 - accuracy: 0.8720 - val_loss: 0.5245 - val_accuracy: 0.6905 - 20s/epoch - 39ms/step
# Epoch 9/10
# 500/500 - 20s - loss: 0.3096 - accuracy: 0.8755 - val_loss: 0.5084 - val_accuracy: 0.7619 - 20s/epoch - 39ms/step
# Epoch 10/10
# 500/500 - 20s - loss: 0.2920 - accuracy: 0.8800 - val_loss: 0.4743 - val_accuracy: 0.8095 - 20s/epoch - 39ms/step
# 11/11 [==============================] - 0s 41ms/step - loss: 0.4743 - accuracy: 0.8095
# Epoch 1/10
# 500/500 - 20s - loss: 0.8258 - accuracy: 0.6455 - val_loss: 0.7073 - val_accuracy: 0.5238 - 20s/epoch - 41ms/step
# Epoch 2/10
# 500/500 - 19s - loss: 0.5886 - accuracy: 0.6890 - val_loss: 0.6650 - val_accuracy: 0.6429 - 19s/epoch - 39ms/step
# Epoch 3/10
# 500/500 - 20s - loss: 0.5348 - accuracy: 0.7405 - val_loss: 0.6425 - val_accuracy: 0.6905 - 20s/epoch - 39ms/step
# Epoch 4/10
# 500/500 - 20s - loss: 0.4951 - accuracy: 0.7695 - val_loss: 0.5902 - val_accuracy: 0.6905 - 20s/epoch - 39ms/step
# Epoch 5/10
# 500/500 - 20s - loss: 0.4527 - accuracy: 0.8005 - val_loss: 0.5715 - val_accuracy: 0.7143 - 20s/epoch - 39ms/step
# Epoch 6/10
# 500/500 - 20s - loss: 0.4212 - accuracy: 0.8195 - val_loss: 0.5477 - val_accuracy: 0.7381 - 20s/epoch - 40ms/step
# Epoch 7/10
# 500/500 - 20s - loss: 0.4044 - accuracy: 0.8275 - val_loss: 0.5201 - val_accuracy: 0.7857 - 20s/epoch - 40ms/step
# Epoch 8/10
# 500/500 - 20s - loss: 0.3782 - accuracy: 0.8385 - val_loss: 0.5169 - val_accuracy: 0.7857 - 20s/epoch - 40ms/step
# Epoch 9/10
# 500/500 - 20s - loss: 0.3665 - accuracy: 0.8490 - val_loss: 0.5049 - val_accuracy: 0.7619 - 20s/epoch - 40ms/step
# Epoch 10/10
# 500/500 - 19s - loss: 0.3399 - accuracy: 0.8645 - val_loss: 0.5237 - val_accuracy: 0.7381 - 19s/epoch - 39ms/step
# 11/11 [==============================] - 0s 39ms/step - loss: 0.5237 - accuracy: 0.7381
# Epoch 1/10
# 500/500 - 21s - loss: 0.9463 - accuracy: 0.5355 - val_loss: 0.6584 - val_accuracy: 0.5714 - 21s/epoch - 42ms/step
# Epoch 2/10
# 500/500 - 19s - loss: 0.4954 - accuracy: 0.7690 - val_loss: 0.6313 - val_accuracy: 0.6190 - 19s/epoch - 39ms/step
# Epoch 3/10
# 500/500 - 20s - loss: 0.4506 - accuracy: 0.8035 - val_loss: 0.6180 - val_accuracy: 0.7143 - 20s/epoch - 39ms/step
# Epoch 4/10
# 500/500 - 20s - loss: 0.4119 - accuracy: 0.8215 - val_loss: 0.6280 - val_accuracy: 0.6905 - 20s/epoch - 39ms/step
# Epoch 5/10
# 500/500 - 20s - loss: 0.3897 - accuracy: 0.8400 - val_loss: 0.5873 - val_accuracy: 0.6905 - 20s/epoch - 40ms/step
# Epoch 6/10
# 500/500 - 20s - loss: 0.3557 - accuracy: 0.8585 - val_loss: 0.6061 - val_accuracy: 0.7143 - 20s/epoch - 40ms/step
# Epoch 7/10
# 500/500 - 20s - loss: 0.3427 - accuracy: 0.8665 - val_loss: 0.5860 - val_accuracy: 0.7619 - 20s/epoch - 40ms/step
# Epoch 8/10
# 500/500 - 20s - loss: 0.3207 - accuracy: 0.8815 - val_loss: 0.5610 - val_accuracy: 0.7381 - 20s/epoch - 39ms/step
# Epoch 9/10
# 500/500 - 20s - loss: 0.3069 - accuracy: 0.8890 - val_loss: 0.5439 - val_accuracy: 0.8095 - 20s/epoch - 40ms/step
# Epoch 10/10
# 500/500 - 20s - loss: 0.2867 - accuracy: 0.8940 - val_loss: 0.5483 - val_accuracy: 0.8095 - 20s/epoch - 40ms/step
# 11/11 [==============================] - 0s 35ms/step - loss: 0.5483 - accuracy: 0.8095
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.median(level=1) should use df.groupby(level=1).median().
#                    0          1  accuracy  macro avg  weighted avg  pos
# precision   0.954248   0.688256  0.795238   0.821252      0.840252  2.0
# recall      0.675000   0.955556  0.795238   0.815278      0.795238  2.0
# f1-score    0.790151   0.799919  0.795238   0.795035      0.794337  2.0
# support    24.000000  18.000000  0.795238  42.000000     42.000000  2.0

# %%
if RunningInCOLAB:
  from google.colab import drive
  drive.mount('/content/drive/')

  # !cp '{model_filename}' "/content/drive/MyDrive/model"
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-24-bcd57274c30d> in <module>()
#       1 if RunningInCOLAB:
#       2   from google.colab import drive
# ----> 3   drive.mount('/content/drive/')
#       4
#       5   get_ipython().system('cp \'{model_filename}\' "/content/drive/MyDrive/model"')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     113       force_remount=force_remount,
#     114       timeout_ms=timeout_ms,
# --> 115       ephemeral=True)
#     116
#     117
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, use_metadata_server, ephemeral)
#     133   if ephemeral:
#     134     _message.blocking_request(
# --> 135         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     136
#     137   mountpoint = _os.path.expanduser(mountpoint)
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     173   request_id = send_request(
#     174       request_type, request, parent=parent, expect_reply=True)
# --> 175   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     104         reply.get('colab_msg_id') == message_id):
#     105       if 'error' in reply:
# --> 106         raise MessageError(reply['error'])
#     107       return reply.get('data', None)
#     108
#
# MessageError: Error: credential propagation was unsuccessful
