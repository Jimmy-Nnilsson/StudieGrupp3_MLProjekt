# %%
# Setup if running in colab
RunningInCOLAB = 'google.colab' in str(get_ipython())
if RunningInCOLAB:
  try:
    if runonce:
      print("Already ran")
  
  except:
    runonce = True
    # !pip install wandb
    # !git clone https://github.com/Jimmy-Nnilsson/StudieGrupp3_MLProjekt.git
    
    import wandb
    wandb.login()

# %%
import wandb
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: bex_team (use `wandb login --relogin` to force relogin)
# True

# %%
import os
import numpy as np
import random
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import tensorflow as tf
print("TF: ", tf.__version__)
from tensorflow.keras import layers
from tensorflow.keras import models
from keras import Model
import keras

from pathlib import Path
from keras.preprocessing.image import load_img, img_to_array, image_dataset_from_directory
from tensorflow.keras.applications import vgg16, vgg19, mobilenet_v2, inception_v3
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import OneHotEncoder

import wandb
from wandb.keras import WandbCallback

import cv2
# Out:
# TF:  2.7.0

# %%
def seed_everything():
    # os.environ['PYTHONHASHSEED'] = '0'
    os.environ['TF_CUDNN_DETERMINISTIC'] = '1' 
    random.seed(1254)
    np.random.seed(hash("improves reproducibility") % 2**32 - 1)
    tf.random.set_seed(hash("by removing stochasticity") % 2**32 - 1)

seed_everything()

# %%
# Get base project directory
if not RunningInCOLAB:
#   project_path = Path(os.getcwd()).parent.parent

  for i, p in enumerate(Path(os.getcwd()).parts):
    if p == "StudieGrupp3_MLProjekt":
        break
    pathparts = list(Path(os.getcwd()).parts[0:i+2])
    project_path = Path(pathparts[0],"\\\\".join(pathparts[1:]))
else:
  project_path = Path('/content/StudieGrupp3_MLProjekt/')
datapath = (project_path /'data/')

CLASSES = {0 : 'no', 1 : 'yes'}
# Loops through pathlist and reads and resizes images
def read_image(pathlist : list, size : int)-> list:
    data = []
    for path in pathlist:
        image=load_img(path, color_mode='rgb', target_size=(size, size))
        # image=load_img(path, color_mode='rgb', target_size=(size, size))
        image=img_to_array(image)
        # image=image/255.0
        data.append(image)
    data = np.asarray(data, dtype=np.uint8)
    return data

# Makes input and label data from folder locations.
# Loops through location "subfolder/CLASSES"
def get_sets(subfolder : str, CLASSES : dict, size : int):
    folder_paths = []
    folder_labels = []
    labels = []
    for k,v in CLASSES.items():
        # input datapath generation
        new_path = (datapath / f"processed/2_split_{v}/{subfolder}")
        folder_paths += list((new_path).rglob("*"))
        list_len = len(list((new_path).rglob("*")))
        folder_labels += [k for i in range(list_len)]
        
        # for i in range(list_len):
        #     folder_labels.append(k)
    # Label data generation
    # folder_labels = [0 if x.stem.split('_')[1] == 'yes' else 1 for x in folder_paths]
    folder_labels = np.asarray(folder_labels, dtype=np.uint8)
    ohe_folder_labels = tf.keras.utils.to_categorical(folder_labels, len(CLASSES))
    # Extract images from datapaths
    img_list = read_image(folder_paths, size)

    return img_list, folder_labels, ohe_folder_labels

def get_training_set(subfolder, CLASSES : dict, size : int):
    folder_paths = []
    folder_labels = []
    labels = []
    for k,v in CLASSES.items():
        # input datapath generation
        # folder_paths += list((datapath / f"3_aug_{v}_train/").rglob("*")) 3_aug_pix_no_train
        new_path = (datapath / f"processed_dataset_2/3_split_{v}/{subfolder}/")
        folder_paths += list((new_path).rglob("*"))
        # print(new_path)
        # print(folder_paths)
    # Label data generation
    folder_labels = [0 if x.stem.split('_')[1] == 'yes' else 1 for x in folder_paths]
    folder_labels = np.asarray(folder_labels, dtype=np.uint8)
    ohe_folder_labels = tf.keras.utils.to_categorical(folder_labels, len(CLASSES))
    # Extract images from datapaths
    img_list = read_image(folder_paths, size)

    return img_list, folder_labels, ohe_folder_labels

# %% [markdown]
# Load Pictures

# %%
# Dataset inspect
# Read images to variables

size = 224
X_train, y_train, y_train_ohe = get_training_set("train",CLASSES, size)
X_val, y_val, y_val_ohe = get_training_set("val", CLASSES, size)
X2_train, y2_train, y2_train_ohe = get_sets('train', CLASSES, size)
X2_val, y2_val, y2_val_ohe = get_sets('val', CLASSES, size)
X_test, y_test, y_test_ohe = get_sets('test', CLASSES, size)

# %% [markdown]
# Data loader

# %%
#@title
@tf.function
def preprocess(image: tf.Tensor, label: tf.Tensor):
    """
    Preprocess the image tensors and parse the labels
    """
    # Preprocess images
    image = tf.image.convert_image_dtype(image, tf.float32)

    # Parse label
    label = tf.cast(label, tf.float32)

    return image, label


def prepare_dataloader(images: np.ndarray,
                       labels: np.ndarray,
                       loader_type: str='train',
                       batch_size: int=128):
    """
    Utility function to prepare dataloader.
    """
    images = model_preprocess(images)
    dataset = tf.data.Dataset.from_tensor_slices((images, labels))

    if loader_type=='train':
        dataset = dataset.shuffle(1024)

    dataloader = (
        dataset
        .map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
        .batch(batch_size)
        .prefetch(tf.data.AUTOTUNE)
    )

    return dataloader

def model_preprocess(images):
    images = vgg19.preprocess_input(images)
    # images = vgg16.preprocess_input(images)
    # images = mobilenet_v2.preprocess_input(images)
    # images = inception_v3.preprocess_input(images)
    
    return images

# %% [markdown]
# Config parameters

# %%
# Mind model processing
# Finetune not complete
configs = dict(
    project_name = "MRI_Baseline_3", #Project Name
    mode = 'disabled', #{'offline', 'run', 'disabled', 'dryrun', 'online'} # WandB run status
    job_type = "", #Run type for WandB
    group = "", # Group in WandB
    sub_group = "_s2_twostep",

    class_names = CLASSES, # Classes for training
    training_set = "",

    image_width = X_train[0].shape[0], # Picture width for model input
    image_height = X_train[0].shape[1], # Picture height for model input
    image_channels = X_train[0].shape[2], # Picture channels for model input

    pretrain_weights = 'imagenet', # pretrained weights for basemodel if any
    batch_size = 4, # Batchsize for training
    init_learning_rate = 0.0004, # Initial training rate if no callback is used
    lr_decay_rate = 0.1, #decayrate of training rate
    epochs = 50, # Epochs to train
    optimizer = 'rmsprop', # The optimizer used by the ml model
    loss_fn = 'CategoricalCrossentropy', # Loss function
    metrics = ['accuracy', 'CategoricalCrossentropy'], # Metrics
    earlystopping_patience = 5, # For the early stopping callback

    dataset = "Brain_MRI_Images_for_Brain_Tumor_Detection",
    fine_tune_learning_rate = 3e-5, # learningrate Used during fine tuning
    fine_tune_epochs = 10, # Epochs ran at finetuning

    architecture = "",# To be defined f"{base_model._name.upper()} global_average_pooling2d",
    model_name = '' # set after model is defined # Name of the ml Model

)

# %% [markdown]
# Model class definition

# %%
class Model_Class():
    def __init__(self,
                 output_activation: str='softmax'
                 ):

        self.shape = (configs['image_width'],configs['image_height'], configs['image_channels'])
        self.model = ""
        # self.base_model = ""
        self.output_activation = output_activation
        self.run = ""
        self.__get_model()
        self.conv_layers, self.layer_names = self.__get_convlayers()
        self.preds = ""
        if not wandb.run is None: wandb.finish()

    def __get_model(self):
        tf.keras.backend.clear_session()
        kwarg = dict(weights=configs['pretrain_weights'], include_top=False, input_shape=self.shape)
        self.base_model = vgg19.VGG19(**kwarg)
        
        self.base_model.trainable = False

        x = layers.GlobalAveragePooling2D()(self.base_model.output)
        # x = layers.Flatten()(self.base_model.output)

        x = layers.Dense(128, activation='relu')(x)
        x = layers.Dense(64, activation='relu')(x)
        x = layers.Dense(32, activation='relu')(x)
        outputs = layers.Dense(2, activation=self.output_activation)(x)
        configs['group'] = f'{self.base_model._name}{configs["sub_group"]}'
        configs['architecture'] = self.base_model._name
        self.model  = models.Model(self.base_model.input, outputs, name=f'Baseline_{self.base_model._name.upper()}')

    def transfer_learning(self,
        dataset, valset,
        callbacks: list,
        verbose: int=0,
        wb: bool=False): # Makes training run on all but base model

        train_config = {
            "learning_rate" : configs['init_learning_rate'],
            "epochs" : configs['epochs'],
            "compile" : True}
        configs['job_type'] = "Transfer learning"

        # self.base_model.trainable = False
        self.__train(dataset=dataset, valset=valset, callbacks=callbacks, verbose=verbose, wb=wb, train_config=train_config)

    def fine_tune(self,
        dataset, valset,
        callbacks: list,
        verbose: int=0,
        wb: bool=False,
        trainable_layers: list=0):

        train_config = {
            "learning_rate" : configs['fine_tune_learning_rate'],
            "epochs" : configs['fine_tune_epochs'],
            'job_type' : 'Fine-tune',
            "compile" : False}
        configs['job_type'] = "Fine-tune"
        self.set_trainable(trainable_layers)
        self.__train(dataset=dataset, valset=valset, callbacks=callbacks, verbose=verbose, wb=wb, train_config=train_config)

    def __train(self,
        dataset, valset,
        callbacks: list,
        verbose: int=0,
        wb: bool=False,
        train_config:dict={}
        ):


        if wb:
            callbacks.append(self.__wandb())

        # Initalize model
        # tf.keras.backend.clear_session()
        configs['model_name'] = self.model._name # set

        # Compile the model
        
        opt = tf.keras.optimizers.RMSprop(learning_rate=train_config['learning_rate'])
        self.model.compile(optimizer=opt,
                    loss=configs['loss_fn'],
                    metrics=configs['metrics'])

        # if not train_config['compile']:
        #     self.model.load_weights(f'model_checkpoint/{model_filename}')
        
        # Train model
        _ = self.model.fit(dataset,
                    epochs=train_config['epochs'],
                    validation_data=valset,
                    callbacks=callbacks,
                    verbose=verbose)
        if wb:
            # Evaluate the trained model
            # loss, acc = self.model.evaluate(validloader)
            # self.run.log({'evaluate/accuracy': acc})


            # Close the W&B run.
            self.run.finish()

    def grad_cam(self, image, layer=None):
        self.preds = self.predict(image)

        if type(layer) is list:
            heatmap_list, superimposed_list = {},{}
            for layer_num in layer:
                heatmap = self.make_gradcam_heatmap(np.expand_dims(image, axis=0), layer_num, np.argmax(self.preds[0]))
                superimposed_img = self.superimpose(image,heatmap)
                heatmap_list[self.model.layers[layer_num]._name] = heatmap
                superimposed_list[self.model.layers[layer_num]._name] = superimposed_img
            return image, heatmap_list, superimposed_list
        else:
            heatmap = self.make_gradcam_heatmap(np.expand_dims(image, axis=0), layer, np.argmax(self.preds[0]))
            superimposed_img = self.superimpose(image,heatmap)
            return image, heatmap, superimposed_img


    def make_gradcam_heatmap(self, img_array, layer=None, pred_index=None):
        # First, we create a model that maps the input image to the activations
        # of the last conv layer as well as the output predictions
        if layer == None: layer=self.conv_layers[-1]
        model = self.model
        grad_model = Model(
            [model.inputs], [model.layers[layer].output, model.output]
            # [model.inputs], [model.get_layer(self.layer_names[-1]).output, model.output]
        )

        # Then, we compute the gradient of the top predicted class for our input image
        # with respect to the activations of the last conv layer
        with tf.GradientTape() as tape:
            last_conv_layer_output, preds = grad_model(img_array)
            if pred_index is None:
                pred_index = tf.argmax(preds[0])
            class_channel = preds[:, pred_index]

        # This is the gradient of the output neuron (top predicted or chosen)
        # with regard to the output feature map of the last conv layer
        grads = tape.gradient(class_channel, last_conv_layer_output)

        # This is a vector where each entry is the mean intensity of the gradient
        # over a specific feature map channel
        pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

        # We multiply each channel in the feature map array
        # by "how important this channel is" with regard to the top predicted class
        # then sum all the channels to obtain the heatmap class activation
        last_conv_layer_output = last_conv_layer_output[0]
        heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
        heatmap = tf.squeeze(heatmap)

        # For visualization purpose, we will also normalize the heatmap between 0 & 1
        heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
        return heatmap.numpy()

    def predict(self, pic):
        x = model_preprocess(pic)
        if len(x.shape) < 4:
          x = np.expand_dims(x, axis=0)
        
        preds = self.model.predict(x)
        return preds

    def superimpose(self, pic,heatmap):
        img_numpy = np.asarray(np.clip(pic, 0, 190))

        heatmap_resized = cv2.resize(heatmap, (img_numpy.shape[1], img_numpy.shape[0]))
        heatmap_resized = np.uint8(255 * heatmap_resized)
        heatmap_resized = cv2.applyColorMap(heatmap_resized, cv2.COLORMAP_JET)

        superimposed_img = 0.3*heatmap_resized[:,:,::-1] + img_numpy
        superimposed_img = superimposed_img.astype(np.uint8)
        return superimposed_img

    def __get_convlayers(self):
        list_conv_layers = []
        list_layer_names = []
        for i,l in enumerate(self.model.layers):
            # print(str(l).split('.'))
            if str(l).split('.')[2] == 'convolutional':
                list_conv_layers.append(i)
                list_layer_names.append(l._name)
        return list_conv_layers, list_layer_names

    def __wandb(self): 
        self.run = wandb.init(mode=configs['mode'] ,project=configs['project_name'], config=configs, job_type=configs['job_type'], group=configs['group'])

        # Define WandbCallback for experiment tracking
        wandb_callback = WandbCallback(monitor='val_loss',
                                    log_weights=True,
                                    log_evaluation=True,
                                    validation_steps=5,
                                    save_model=True,
                                    save_graph = True
                                    )
        return wandb_callback

    def set_trainable(self, trainable_layers=0): # Sets whole model to trainable
        if trainable_layers == 0:
            self.model.trainable = True
        else:
            self.model.trainable = False
            for i in trainable_layers:
                self.model.layers[i].trainable = True

# %% [markdown]
# Call model

# %%
model = Model_Class()

# %% [markdown]
# Model Callbacks

# %%
earlystopper = keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=configs['earlystopping_patience'], verbose=0, mode='auto',
    restore_best_weights=True
)

# %%
def lr_scheduler(epoch, lr):
    # log the current learning rate onto W&B
    if wandb.run is None:
        raise wandb.Error("You must call wandb.init() before WandbCallback()")

    wandb.log({'learning_rate': lr}, commit=False)

    if epoch < 12:
        return lr
    else:
        return lr * tf.math.exp(-configs['lr_decay_rate'])

lr_callback = tf.keras.callbacks.LearningRateScheduler(lr_scheduler)

# %% [markdown]
# Make gradcams

# %%
def plot_gradcam(image, heatmap, superimposed_img):
  if type(heatmap) == dict and type(superimposed_img) == dict:
      nlen = len(heatmap)
      fig, ax = plt.subplots(nlen,3, figsize=(10, nlen*3.5))
      # fig.figsize=(20,20)
      for i, (k, img) in enumerate(heatmap.items()):
          ax[i,0].imshow(img)
          ax[i,1].set_title(k)
          ax[i,1].imshow(superimposed_img[k])
          ax[i,2].imshow(image)
  else:
    plt.subplot(1,3, 1)
    plt.imshow(heatmap)
    plt.subplot(1,3, 2)
    plt.imshow(superimposed_img)
    plt.subplot(1,3, 3)
    plt.imshow(image)

# %% [markdown]
# Plot gradcams

# %%
import seaborn as sns

def crcm(model, x, y):
    y_pred = model.predict(x)
    y_pred = [np.argmax(pred) for pred in y_pred]
    # y_pred = CLASSES[np.argmax()]
    # y_pred = np.asarray(y_pred)
    # y_pred = np.uint8(y_pred+0.5)
    cm = confusion_matrix(y, y_pred)
    CLASSNAMES = list(CLASSES.values())
    cr = classification_report(y, y_pred, target_names=CLASSNAMES)
    plt.xlabel('Pred')
    s = sns.heatmap(cm, vmin=0, annot=True, xticklabels=CLASSNAMES, yticklabels=CLASSNAMES)
    s.set(xlabel='Pred', ylabel='Actual')
    print(cr)

# %%
crcm(model, X_val, y_val)
# Out:
#               precision    recall  f1-score   support
#
#           no       0.82      0.30      0.44       987
#          yes       0.28      0.81      0.41       330
#
#     accuracy                           0.43      1317
#    macro avg       0.55      0.55      0.43      1317
# weighted avg       0.69      0.43      0.43      1317

# %%
trainloader = prepare_dataloader(X_train, y_train_ohe, 'train', configs.get('batch_size', 64))
validloader = prepare_dataloader(X_val, y_val_ohe, 'valid', configs.get('batch_size', 64))
testloader = prepare_dataloader(X_test, y_test_ohe, 'test', configs.get('batch_size', 64))

# %%
model_filename = f'{model.base_model._name}_{configs["project_name"]}{configs["sub_group"]}.h5'
if not RunningInCOLAB:
  checkpoint_filepath = (Path(os.getcwd()) /f'model_checkpoint/{model_filename}_step1')
else:
  checkpoint_filepath = (Path(f'/content/{model_filename}_step1'))

model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %% [markdown]
# Train with wandb

# %%
bp = 18

for i, l in enumerate(model.model.layers):
    if i <= bp:
        l.trainable = False
    else:
        l.trainable = True

# for l in model.model.layers:
    # print(l ,l.trainable)

# callbacks = [earlystopper]
# model.base_model.trainable = False
callbacks = [model_checkpoint_callback]

# Train
# model.train(callbacks=callbacks, verbose=2, wb=True)
model.transfer_learning(trainloader, validloader, callbacks=callbacks, verbose=2, wb=True)
model.model.summary()
model.model.load_weights(f'model_checkpoint/{model_filename}_step1')
crcm(model, X_val, y_val)
# Out:
# Epoch 1/50
# 987/987 - 59s - loss: 0.4882 - accuracy: 0.9271 - categorical_crossentropy: 0.4882 - val_loss: 0.3218 - val_accuracy: 0.9453 - val_categorical_crossentropy: 0.3218 - 59s/epoch - 60ms/step
# Epoch 2/50
# 987/987 - 57s - loss: 0.1958 - accuracy: 0.9739 - categorical_crossentropy: 0.1958 - val_loss: 0.0980 - val_accuracy: 0.9856 - val_categorical_crossentropy: 0.0980 - 57s/epoch - 58ms/step
# Epoch 3/50
# 987/987 - 58s - loss: 0.1248 - accuracy: 0.9825 - categorical_crossentropy: 0.1248 - val_loss: 0.1727 - val_accuracy: 0.9886 - val_categorical_crossentropy: 0.1727 - 58s/epoch - 58ms/step
# Epoch 4/50
# 987/987 - 56s - loss: 0.1012 - accuracy: 0.9856 - categorical_crossentropy: 0.1012 - val_loss: 0.3218 - val_accuracy: 0.9727 - val_categorical_crossentropy: 0.3218 - 56s/epoch - 57ms/step
# Epoch 5/50
# 987/987 - 54s - loss: 0.0978 - accuracy: 0.9906 - categorical_crossentropy: 0.0978 - val_loss: 0.1440 - val_accuracy: 0.9658 - val_categorical_crossentropy: 0.1440 - 54s/epoch - 55ms/step
# Epoch 6/50
# 987/987 - 54s - loss: 0.1147 - accuracy: 0.9916 - categorical_crossentropy: 0.1147 - val_loss: 0.1775 - val_accuracy: 0.9863 - val_categorical_crossentropy: 0.1775 - 54s/epoch - 55ms/step
# Epoch 7/50
# 987/987 - 55s - loss: 0.0620 - accuracy: 0.9932 - categorical_crossentropy: 0.0620 - val_loss: 0.6625 - val_accuracy: 0.9856 - val_categorical_crossentropy: 0.6625 - 55s/epoch - 55ms/step
# Epoch 8/50
# 987/987 - 54s - loss: 0.1256 - accuracy: 0.9929 - categorical_crossentropy: 0.1256 - val_loss: 0.4074 - val_accuracy: 0.9886 - val_categorical_crossentropy: 0.4074 - 54s/epoch - 55ms/step
# Epoch 9/50
# 987/987 - 57s - loss: 0.1279 - accuracy: 0.9932 - categorical_crossentropy: 0.1279 - val_loss: 0.3783 - val_accuracy: 0.9901 - val_categorical_crossentropy: 0.3783 - 57s/epoch - 58ms/step
# Epoch 10/50
# 987/987 - 59s - loss: 0.1018 - accuracy: 0.9959 - categorical_crossentropy: 0.1018 - val_loss: 0.3951 - val_accuracy: 0.9909 - val_categorical_crossentropy: 0.3951 - 59s/epoch - 59ms/step
# Epoch 11/50
# 987/987 - 55s - loss: 0.0710 - accuracy: 0.9952 - categorical_crossentropy: 0.0710 - val_loss: 0.4325 - val_accuracy: 0.9909 - val_categorical_crossentropy: 0.4325 - 55s/epoch - 55ms/step
# Epoch 12/50
# 987/987 - 55s - loss: 0.0596 - accuracy: 0.9965 - categorical_crossentropy: 0.0596 - val_loss: 0.6717 - val_accuracy: 0.9879 - val_categorical_crossentropy: 0.6717 - 55s/epoch - 56ms/step
# Epoch 13/50
# 987/987 - 56s - loss: 0.0385 - accuracy: 0.9962 - categorical_crossentropy: 0.0385 - val_loss: 0.5558 - val_accuracy: 0.9924 - val_categorical_crossentropy: 0.5558 - 56s/epoch - 57ms/step
# Epoch 14/50
# 987/987 - 58s - loss: 0.0431 - accuracy: 0.9965 - categorical_crossentropy: 0.0431 - val_loss: 0.4494 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.4494 - 58s/epoch - 59ms/step
# Epoch 15/50
# 987/987 - 58s - loss: 0.0628 - accuracy: 0.9980 - categorical_crossentropy: 0.0628 - val_loss: 0.2891 - val_accuracy: 0.9939 - val_categorical_crossentropy: 0.2891 - 58s/epoch - 59ms/step
# Epoch 16/50
# 987/987 - 57s - loss: 0.0344 - accuracy: 0.9970 - categorical_crossentropy: 0.0344 - val_loss: 2.2155 - val_accuracy: 0.9598 - val_categorical_crossentropy: 2.2155 - 57s/epoch - 57ms/step
# Epoch 17/50
# 987/987 - 54s - loss: 0.0138 - accuracy: 0.9987 - categorical_crossentropy: 0.0138 - val_loss: 0.5198 - val_accuracy: 0.9916 - val_categorical_crossentropy: 0.5198 - 54s/epoch - 55ms/step
# Epoch 18/50
# 987/987 - 56s - loss: 2.6269e-09 - accuracy: 1.0000 - categorical_crossentropy: 2.6269e-09 - val_loss: 0.9500 - val_accuracy: 0.9901 - val_categorical_crossentropy: 0.9500 - 56s/epoch - 57ms/step
# Epoch 19/50
# 987/987 - 55s - loss: 0.0282 - accuracy: 0.9990 - categorical_crossentropy: 0.0282 - val_loss: 0.7168 - val_accuracy: 0.9916 - val_categorical_crossentropy: 0.7168 - 55s/epoch - 56ms/step
# Epoch 20/50
# 987/987 - 53s - loss: 0.0612 - accuracy: 0.9975 - categorical_crossentropy: 0.0612 - val_loss: 0.6492 - val_accuracy: 0.9901 - val_categorical_crossentropy: 0.6492 - 53s/epoch - 54ms/step
# Epoch 21/50
# 987/987 - 60s - loss: 0.0207 - accuracy: 0.9985 - categorical_crossentropy: 0.0207 - val_loss: 1.0478 - val_accuracy: 0.9916 - val_categorical_crossentropy: 1.0478 - 60s/epoch - 60ms/step
# Epoch 22/50
# 987/987 - 54s - loss: 0.0891 - accuracy: 0.9980 - categorical_crossentropy: 0.0891 - val_loss: 0.7887 - val_accuracy: 0.9916 - val_categorical_crossentropy: 0.7887 - 54s/epoch - 54ms/step
# Epoch 23/50
# 987/987 - 54s - loss: 2.2949e-07 - accuracy: 1.0000 - categorical_crossentropy: 2.2949e-07 - val_loss: 0.7728 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.7728 - 54s/epoch - 55ms/step
# Epoch 24/50
# 987/987 - 54s - loss: 0.0057 - accuracy: 0.9997 - categorical_crossentropy: 0.0057 - val_loss: 0.7115 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.7115 - 54s/epoch - 55ms/step
# Epoch 25/50
# 987/987 - 55s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 0.7141 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.7141 - 55s/epoch - 55ms/step
# Epoch 26/50
# 987/987 - 54s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 0.7162 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.7162 - 54s/epoch - 55ms/step
# Epoch 27/50
# 987/987 - 55s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 0.7179 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.7179 - 55s/epoch - 56ms/step
# Epoch 28/50
# 987/987 - 54s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 0.7194 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.7194 - 54s/epoch - 55ms/step
# Epoch 29/50
# 987/987 - 55s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 0.7207 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.7207 - 55s/epoch - 56ms/step
# Epoch 30/50
# 987/987 - 54s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 0.7219 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.7219 - 54s/epoch - 55ms/step
# Epoch 31/50
# 987/987 - 54s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 0.7229 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.7229 - 54s/epoch - 55ms/step
# Epoch 32/50
# 987/987 - 54s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 0.7238 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.7238 - 54s/epoch - 54ms/step
# Epoch 33/50
# 987/987 - 54s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 0.7247 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.7247 - 54s/epoch - 55ms/step
# Epoch 34/50
# 987/987 - 54s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 0.7255 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.7255 - 54s/epoch - 55ms/step
# Epoch 35/50
# 987/987 - 54s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 0.7262 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.7262 - 54s/epoch - 54ms/step
# Epoch 36/50
# 987/987 - 54s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 0.7270 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.7270 - 54s/epoch - 55ms/step
# Epoch 37/50
# 987/987 - 54s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 0.7277 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.7277 - 54s/epoch - 55ms/step
# Epoch 38/50
# 987/987 - 54s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 0.7283 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.7283 - 54s/epoch - 55ms/step
# Epoch 39/50
# 987/987 - 54s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 0.7289 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.7289 - 54s/epoch - 55ms/step
# Epoch 40/50
# 987/987 - 55s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 0.7295 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.7295 - 55s/epoch - 55ms/step
# Epoch 41/50
# 987/987 - 55s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 0.7301 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.7301 - 55s/epoch - 56ms/step
# Epoch 42/50
# 987/987 - 55s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 0.7306 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.7306 - 55s/epoch - 56ms/step
# Epoch 43/50
# 987/987 - 55s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 0.7311 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.7311 - 55s/epoch - 56ms/step
# Epoch 44/50
# 987/987 - 54s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 0.7315 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.7315 - 54s/epoch - 55ms/step
# Epoch 45/50
# 987/987 - 55s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 0.7322 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.7322 - 55s/epoch - 56ms/step
# Epoch 46/50
# 987/987 - 55s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 0.7328 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.7328 - 55s/epoch - 55ms/step
# Epoch 47/50
# 987/987 - 56s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 0.7334 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.7334 - 56s/epoch - 57ms/step
# Epoch 48/50
# 987/987 - 55s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 0.7338 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.7338 - 55s/epoch - 56ms/step
# Epoch 49/50
# 987/987 - 55s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 0.7343 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.7343 - 55s/epoch - 56ms/step
# Epoch 50/50
# 987/987 - 55s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 0.7347 - val_accuracy: 0.9932 - val_categorical_crossentropy: 0.7347 - 55s/epoch - 56ms/step
# Model: "Baseline_VGG19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               65664
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 20,100,450
# Trainable params: 4,795,682
# Non-trainable params: 15,304,768
# _________________________________________________________________
#               precision    recall  f1-score   support
#
#           no       0.99      1.00      1.00       987
#          yes       0.99      0.98      0.99       330
#
#     accuracy                           0.99      1317
#    macro avg       0.99      0.99      0.99      1317
# weighted avg       0.99      0.99      0.99      1317

# %%
model.model.save(f'model_step1/{model_filename}')

# %%
model.model.load_weights(f'model_step1/{model_filename}')

# %%
trainloader = prepare_dataloader(X2_train, y2_train_ohe, 'train', configs.get('batch_size', 64))
validloader = prepare_dataloader(X2_val, y2_val_ohe, 'valid', configs.get('batch_size', 64))

# %%
model_filename = f'{model.base_model._name}_{configs["project_name"]}{configs["sub_group"]}.h5'
if not RunningInCOLAB:
  checkpoint_filepath = (Path(os.getcwd()) /f'model_checkpoint/{model_filename}_step2')
else:
  checkpoint_filepath = (Path(f'/content/{model_filename}_step2'))

model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %%
bp = 18

for i, l in enumerate(model.model.layers):
    if i <= bp:
        l.trainable = False
    else:
        l.trainable = True
# model.base_model.trainable = False
# for l in model.model.layers:
#     print(l.trainable)

# callbacks = [earlystopper]
callbacks = [model_checkpoint_callback]

# Train
# model.train(callbacks=callbacks, verbose=2, wb=True)
model.transfer_learning(trainloader, validloader, callbacks=callbacks, verbose=2, wb=True)
model.model.summary()
model.model.load_weights(f'model_checkpoint/{model_filename}_step2')
crcm(model, X2_val, y2_val)
# Out:
# Epoch 1/50
# 32/32 - 7s - loss: 9.4508 - accuracy: 0.5680 - categorical_crossentropy: 9.4508 - val_loss: 1.1634 - val_accuracy: 0.5714 - val_categorical_crossentropy: 1.1634 - 7s/epoch - 208ms/step
# Epoch 2/50
# 32/32 - 2s - loss: 0.7187 - accuracy: 0.6640 - categorical_crossentropy: 0.7187 - val_loss: 1.7265 - val_accuracy: 0.5000 - val_categorical_crossentropy: 1.7265 - 2s/epoch - 75ms/step
# Epoch 3/50
# 32/32 - 4s - loss: 0.6993 - accuracy: 0.6880 - categorical_crossentropy: 0.6993 - val_loss: 0.8466 - val_accuracy: 0.6429 - val_categorical_crossentropy: 0.8466 - 4s/epoch - 137ms/step
# Epoch 4/50
# 32/32 - 2s - loss: 0.6340 - accuracy: 0.8080 - categorical_crossentropy: 0.6340 - val_loss: 1.3803 - val_accuracy: 0.6190 - val_categorical_crossentropy: 1.3803 - 2s/epoch - 75ms/step
# Epoch 5/50
# 32/32 - 4s - loss: 0.3918 - accuracy: 0.8640 - categorical_crossentropy: 0.3918 - val_loss: 0.3808 - val_accuracy: 0.8095 - val_categorical_crossentropy: 0.3808 - 4s/epoch - 132ms/step
# Epoch 6/50
# 32/32 - 5s - loss: 0.2139 - accuracy: 0.9120 - categorical_crossentropy: 0.2139 - val_loss: 0.4140 - val_accuracy: 0.8810 - val_categorical_crossentropy: 0.4140 - 5s/epoch - 144ms/step
# Epoch 7/50
# 32/32 - 3s - loss: 0.5406 - accuracy: 0.9040 - categorical_crossentropy: 0.5406 - val_loss: 0.3070 - val_accuracy: 0.8333 - val_categorical_crossentropy: 0.3070 - 3s/epoch - 81ms/step
# Epoch 8/50
# 32/32 - 4s - loss: 0.0904 - accuracy: 0.9600 - categorical_crossentropy: 0.0904 - val_loss: 0.3159 - val_accuracy: 0.9048 - val_categorical_crossentropy: 0.3159 - 4s/epoch - 128ms/step
# Epoch 9/50
# 32/32 - 4s - loss: 0.1183 - accuracy: 0.9600 - categorical_crossentropy: 0.1183 - val_loss: 0.4002 - val_accuracy: 0.9286 - val_categorical_crossentropy: 0.4002 - 4s/epoch - 135ms/step
# Epoch 10/50
# 32/32 - 2s - loss: 0.0602 - accuracy: 0.9680 - categorical_crossentropy: 0.0602 - val_loss: 0.4024 - val_accuracy: 0.9048 - val_categorical_crossentropy: 0.4024 - 2s/epoch - 77ms/step
# Epoch 11/50
# 32/32 - 2s - loss: 0.0557 - accuracy: 0.9840 - categorical_crossentropy: 0.0557 - val_loss: 0.9887 - val_accuracy: 0.8810 - val_categorical_crossentropy: 0.9887 - 2s/epoch - 73ms/step
# Epoch 12/50
# 32/32 - 2s - loss: 0.0285 - accuracy: 0.9920 - categorical_crossentropy: 0.0285 - val_loss: 1.8537 - val_accuracy: 0.8571 - val_categorical_crossentropy: 1.8537 - 2s/epoch - 76ms/step
# Epoch 13/50
# 32/32 - 2s - loss: 0.0919 - accuracy: 0.9520 - categorical_crossentropy: 0.0919 - val_loss: 1.2585 - val_accuracy: 0.8571 - val_categorical_crossentropy: 1.2585 - 2s/epoch - 76ms/step
# Epoch 14/50
# 32/32 - 2s - loss: 0.0098 - accuracy: 1.0000 - categorical_crossentropy: 0.0098 - val_loss: 0.9138 - val_accuracy: 0.8810 - val_categorical_crossentropy: 0.9138 - 2s/epoch - 74ms/step
# Epoch 15/50
# 32/32 - 3s - loss: 0.0054 - accuracy: 1.0000 - categorical_crossentropy: 0.0054 - val_loss: 0.7991 - val_accuracy: 0.8810 - val_categorical_crossentropy: 0.7991 - 3s/epoch - 81ms/step
# Epoch 16/50
# 32/32 - 2s - loss: 3.5707e-04 - accuracy: 1.0000 - categorical_crossentropy: 3.5707e-04 - val_loss: 1.1063 - val_accuracy: 0.8571 - val_categorical_crossentropy: 1.1063 - 2s/epoch - 78ms/step
# Epoch 17/50
# 32/32 - 2s - loss: 1.5018e-05 - accuracy: 1.0000 - categorical_crossentropy: 1.5018e-05 - val_loss: 1.3966 - val_accuracy: 0.8571 - val_categorical_crossentropy: 1.3966 - 2s/epoch - 73ms/step
# Epoch 18/50
# 32/32 - 2s - loss: 2.0894e-06 - accuracy: 1.0000 - categorical_crossentropy: 2.0894e-06 - val_loss: 1.8633 - val_accuracy: 0.8571 - val_categorical_crossentropy: 1.8633 - 2s/epoch - 70ms/step
# Epoch 19/50
# 32/32 - 2s - loss: 1.6785e-07 - accuracy: 1.0000 - categorical_crossentropy: 1.6785e-07 - val_loss: 2.2990 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.2990 - 2s/epoch - 65ms/step
# Epoch 20/50
# 32/32 - 2s - loss: 1.3351e-08 - accuracy: 1.0000 - categorical_crossentropy: 1.3351e-08 - val_loss: 2.3244 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.3244 - 2s/epoch - 67ms/step
# Epoch 21/50
# 32/32 - 2s - loss: 5.7220e-09 - accuracy: 1.0000 - categorical_crossentropy: 5.7220e-09 - val_loss: 2.4241 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.4241 - 2s/epoch - 67ms/step
# Epoch 22/50
# 32/32 - 2s - loss: 2.8610e-09 - accuracy: 1.0000 - categorical_crossentropy: 2.8610e-09 - val_loss: 2.5950 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.5950 - 2s/epoch - 69ms/step
# Epoch 23/50
# 32/32 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 2.6999 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.6999 - 2s/epoch - 71ms/step
# Epoch 24/50
# 32/32 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 2.7439 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.7439 - 2s/epoch - 65ms/step
# Epoch 25/50
# 32/32 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 2.8058 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.8058 - 2s/epoch - 66ms/step
# Epoch 26/50
# 32/32 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 2.8206 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.8206 - 2s/epoch - 65ms/step
# Epoch 27/50
# 32/32 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 2.8540 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.8540 - 2s/epoch - 65ms/step
# Epoch 28/50
# 32/32 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 2.8730 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.8730 - 2s/epoch - 65ms/step
# Epoch 29/50
# 32/32 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 2.8842 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.8842 - 2s/epoch - 66ms/step
# Epoch 30/50
# 32/32 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 2.8850 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.8850 - 2s/epoch - 65ms/step
# Epoch 31/50
# 32/32 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 2.8870 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.8870 - 2s/epoch - 70ms/step
# Epoch 32/50
# 32/32 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 2.8939 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.8939 - 2s/epoch - 68ms/step
# Epoch 33/50
# 32/32 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 2.8988 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.8988 - 2s/epoch - 65ms/step
# Epoch 34/50
# 32/32 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 2.9049 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.9049 - 2s/epoch - 66ms/step
# Epoch 35/50
# 32/32 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 2.9111 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.9111 - 2s/epoch - 66ms/step
# Epoch 36/50
# 32/32 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 2.9150 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.9150 - 2s/epoch - 65ms/step
# Epoch 37/50
# 32/32 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 2.9165 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.9165 - 2s/epoch - 66ms/step
# Epoch 38/50
# 32/32 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 2.9188 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.9188 - 2s/epoch - 66ms/step
# Epoch 39/50
# 32/32 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 2.9220 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.9220 - 2s/epoch - 65ms/step
# Epoch 40/50
# 32/32 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 2.9256 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.9256 - 2s/epoch - 67ms/step
# Epoch 41/50
# 32/32 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 2.9286 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.9286 - 2s/epoch - 66ms/step
# Epoch 42/50
# 32/32 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 2.9313 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.9313 - 2s/epoch - 65ms/step
# Epoch 43/50
# 32/32 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 2.9343 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.9343 - 2s/epoch - 65ms/step
# Epoch 44/50
# 32/32 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 2.9373 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.9373 - 2s/epoch - 65ms/step
# Epoch 45/50
# 32/32 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 2.9392 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.9392 - 2s/epoch - 65ms/step
# Epoch 46/50
# 32/32 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 2.9417 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.9417 - 2s/epoch - 65ms/step
# Epoch 47/50
# 32/32 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 2.9450 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.9450 - 2s/epoch - 65ms/step
# Epoch 48/50
# 32/32 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 2.9478 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.9478 - 2s/epoch - 66ms/step
# Epoch 49/50
# 32/32 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 2.9503 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.9503 - 2s/epoch - 66ms/step
# Epoch 50/50
# 32/32 - 2s - loss: 0.0000e+00 - accuracy: 1.0000 - categorical_crossentropy: 0.0000e+00 - val_loss: 2.9532 - val_accuracy: 0.8810 - val_categorical_crossentropy: 2.9532 - 2s/epoch - 66ms/step
# Model: "Baseline_VGG19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               65664
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 20,100,450
# Trainable params: 4,795,682
# Non-trainable params: 15,304,768
# _________________________________________________________________
#               precision    recall  f1-score   support
#
#           no       0.86      1.00      0.92        18
#          yes       1.00      0.88      0.93        24
#
#     accuracy                           0.93        42
#    macro avg       0.93      0.94      0.93        42
# weighted avg       0.94      0.93      0.93        42

# %%
crcm(model, X_test, y_test)
# X_test, y_test, y_test_ohe = get_sets('test', CLASSES, size)
# Out:
#               precision    recall  f1-score   support
#
#           no       0.92      1.00      0.96        12
#          yes       1.00      0.97      0.98        30
#
#     accuracy                           0.98        42
#    macro avg       0.96      0.98      0.97        42
# weighted avg       0.98      0.98      0.98        42

# %%
model.model.save(f'model_step2/{model_filename}')

# %%
if RunningInCOLAB:
  from google.colab import drive
  drive.mount('/content/drive/')

  # !cp '{model_filename}' "/content/drive/MyDrive/model"
